# %%
import sys
import os
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
    sys.path.append(repo_root)

from liars_poker import GameSpec, RandomPolicy, Env
from liars_poker.simple_api import start_run, build_best_response, mix_policies, play_vs_bot
from liars_poker.br import best_response_mc
import random

# %%
import os
from collections import defaultdict
from liars_poker.simple_api import mix_policies
from liars_poker.eval import eval_both_seats
from liars_poker.env import Env, rules_for_spec
from liars_poker.logging import load_json

def harmonic_eta(t: int, c: float = 1.0) -> float:
    """η_t = c / (t+1)"""
    return c / (t + 1)

def fsp_step(
    run,
    spec: GameSpec,
    opponent_policy,             # current average
    *,
    episodes: int = 20_000,
    epsilon: float = 0.1,
    min_visits_per_action: int = 1,
    eta: float = 0.05,
    mix_impl: str = "commit_once",
    seed: int = 0,
):
    """Build BR vs 'opponent_policy', log it, mix with weight eta, log new average; return (br, new_avg)."""

    br, V = best_response_mc(
        spec, opponent_policy,
        episodes=episodes,
        epsilon=epsilon,
        min_visits_per_action=min_visits_per_action,
        alternate_seats=True,
        seed=seed,
    )

    # 2) Log BR (as Bk)
    cur_avg_id = run.current_policy_id
    b_id = run.log_policy(
        br,
        role="best_response",
        parents=[{"id": cur_avg_id, "role": "avg", "weight": 1.0}],
        notes=f"MC-BR vs {cur_avg_id}; episodes={episodes}, eps={epsilon}, seed={seed}",
        seed=seed,
    )

    manifest_dir = run.manifests_dir

    def expand_entry(entry):
        pid = entry["id"]
        role = entry.get("role", "avg")
        weight = entry["weight"]
        if weight <= 0:
            return []
        if role != "avg":
            return [(pid, role, weight)]
        manifest_path = os.path.join(manifest_dir, f"{pid}.json")
        data = load_json(manifest_path)
        parents = data.get("parents", [])
        if not parents:
            leaf_role = data.get("role", role)
            return [(pid, leaf_role, weight)]
        expanded = []
        for parent in parents:
            child_entry = {
                "id": parent["id"],
                "role": parent.get("role", "avg"),
                "weight": parent["weight"],
            }
            for cid, crole, cw in expand_entry(child_entry):
                expanded.append((cid, crole, weight * cw))
        return expanded

    # 3) Mix into new average (Ak+1)
    new_avg = mix_policies(opponent_policy, br, {"impl": mix_impl, "w": eta})

    parent_contribs = defaultdict(float)

    if (1.0 - eta) > 0:
        for pid, role, weight in expand_entry({"id": cur_avg_id, "role": "avg", "weight": 1.0 - eta}):
            parent_contribs[(pid, role)] += weight

    if eta > 0:
        parent_contribs[(b_id, "br")] += eta

    parents_for_log = [
        {"id": pid, "role": role, "weight": parent_contribs[(pid, role)]}
        for (pid, role) in sorted(parent_contribs.keys())
        if parent_contribs[(pid, role)] > 0
    ]

    a_id = run.log_policy(
        new_avg,
        role="average",
        parents=parents_for_log,
        mixing={"impl": mix_impl, "schedule": "manual", "eta_k": eta},
        notes=f"A' = (1-{eta})*{cur_avg_id} + {eta}*{b_id}",
        seed=seed,
    )

    return br, new_avg, b_id, a_id, V

# %%
seed = 42
spec = GameSpec(ranks=3, suits=4, hand_size=1, starter='P1', claim_kinds=("RankHigh","Pair"))

# %%
run = start_run(spec, save_root=os.path.join(repo_root, "artifacts"), seed=seed)
a0_id = run.log_policy(
    RandomPolicy(),
    role="average",
    seed=seed,
    notes="Initial average: RandomPolicy",
)
print("Logged:", a0_id)

cur = run.current_policy()
print("Loaded current policy type:", type(cur).__name__)
# Out:
# Logged: A0
# Loaded current policy type: RandomPolicy

# %%
# reproducible RNG stream for the loop
base_seed = seed
rules = rules_for_spec(spec)   # bind once (policies/env reuse this)

# optional quick eval helper

iters = 50

cur = run.current_policy()
for t in range(iters):
    eta_t = harmonic_eta(t)
    print(f"\n=== Iteration {t} | eta={eta_t:.4f} ===")

    br, new_avg, b_id, a_id, V = fsp_step(
        run, spec, cur,
        episodes=10_000+4000*t,
        epsilon=0.1,
        min_visits_per_action=1,
        eta=eta_t,
        mix_impl="commit_once",
        seed=base_seed + t,
    )

    w_br_vs_cur = eval_both_seats(spec, br, cur, episodes=2000, seed=base_seed + 911*t)
    print("BR vs current avg (candidate perspective):", w_br_vs_cur)


    cur = new_avg  # advance average
    print(f"Logged BR={b_id}, new AVG={a_id}")

print("\nDone. Latest average policy id:", run.current_policy_id)
# Out:
# === Iteration 0 | eta=1.0000 ===
# BR vs current avg (candidate perspective): {'A': 1691, 'B': 309, 'total': 2000}
# Logged BR=B0, new AVG=A1
#
# === Iteration 1 | eta=0.5000 ===
# BR vs current avg (candidate perspective): {'A': 1437, 'B': 563, 'total': 2000}
# Logged BR=B1, new AVG=A2
#
# === Iteration 2 | eta=0.3333 ===
# BR vs current avg (candidate perspective): {'A': 1317, 'B': 683, 'total': 2000}
# Logged BR=B2, new AVG=A3
#
# === Iteration 3 | eta=0.2500 ===
# BR vs current avg (candidate perspective): {'A': 1251, 'B': 749, 'total': 2000}
# Logged BR=B3, new AVG=A4
#
# === Iteration 4 | eta=0.2000 ===
# BR vs current avg (candidate perspective): {'A': 1226, 'B': 774, 'total': 2000}
# Logged BR=B4, new AVG=A5
#
# === Iteration 5 | eta=0.1667 ===
# BR vs current avg (candidate perspective): {'A': 1204, 'B': 796, 'total': 2000}
# Logged BR=B5, new AVG=A6
#
# === Iteration 6 | eta=0.1429 ===
# BR vs current avg (candidate perspective): {'A': 1207, 'B': 793, 'total': 2000}
# Logged BR=B6, new AVG=A7
#
# === Iteration 7 | eta=0.1250 ===
# BR vs current avg (candidate perspective): {'A': 1164, 'B': 836, 'total': 2000}
# Logged BR=B7, new AVG=A8
#
# === Iteration 8 | eta=0.1111 ===
# BR vs current avg (candidate perspective): {'A': 1202, 'B': 798, 'total': 2000}
# Logged BR=B8, new AVG=A9
#
# === Iteration 9 | eta=0.1000 ===
# BR vs current avg (candidate perspective): {'A': 1144, 'B': 856, 'total': 2000}
# Logged BR=B9, new AVG=A10
#
# === Iteration 10 | eta=0.0909 ===
# BR vs current avg (candidate perspective): {'A': 1145, 'B': 855, 'total': 2000}
# Logged BR=B10, new AVG=A11
#
# === Iteration 11 | eta=0.0833 ===
# BR vs current avg (candidate perspective): {'A': 1148, 'B': 852, 'total': 2000}
# Logged BR=B11, new AVG=A12
#
# === Iteration 12 | eta=0.0769 ===
# BR vs current avg (candidate perspective): {'A': 1164, 'B': 836, 'total': 2000}
# Logged BR=B12, new AVG=A13
#
# === Iteration 13 | eta=0.0714 ===
# BR vs current avg (candidate perspective): {'A': 1144, 'B': 856, 'total': 2000}
# Logged BR=B13, new AVG=A14
#
# === Iteration 14 | eta=0.0667 ===
# BR vs current avg (candidate perspective): {'A': 1089, 'B': 911, 'total': 2000}
# Logged BR=B14, new AVG=A15
#
# === Iteration 15 | eta=0.0625 ===
# BR vs current avg (candidate perspective): {'A': 1089, 'B': 911, 'total': 2000}
# Logged BR=B15, new AVG=A16
#
# === Iteration 16 | eta=0.0588 ===
# BR vs current avg (candidate perspective): {'A': 1122, 'B': 878, 'total': 2000}
# Logged BR=B16, new AVG=A17
#
# === Iteration 17 | eta=0.0556 ===
# BR vs current avg (candidate perspective): {'A': 1126, 'B': 874, 'total': 2000}
# Logged BR=B17, new AVG=A18
#
# === Iteration 18 | eta=0.0526 ===
# BR vs current avg (candidate perspective): {'A': 1109, 'B': 891, 'total': 2000}
# Logged BR=B18, new AVG=A19
#
# === Iteration 19 | eta=0.0500 ===
# BR vs current avg (candidate perspective): {'A': 1122, 'B': 878, 'total': 2000}
# Logged BR=B19, new AVG=A20
#
# === Iteration 20 | eta=0.0476 ===
# BR vs current avg (candidate perspective): {'A': 1047, 'B': 953, 'total': 2000}
# Logged BR=B20, new AVG=A21
#
# === Iteration 21 | eta=0.0455 ===
# BR vs current avg (candidate perspective): {'A': 1100, 'B': 900, 'total': 2000}
# Logged BR=B21, new AVG=A22
#
# === Iteration 22 | eta=0.0435 ===
# BR vs current avg (candidate perspective): {'A': 1097, 'B': 903, 'total': 2000}
# Logged BR=B22, new AVG=A23
#
# === Iteration 23 | eta=0.0417 ===
# BR vs current avg (candidate perspective): {'A': 1121, 'B': 879, 'total': 2000}
# Logged BR=B23, new AVG=A24
#
# === Iteration 24 | eta=0.0400 ===
# BR vs current avg (candidate perspective): {'A': 1079, 'B': 921, 'total': 2000}
# Logged BR=B24, new AVG=A25
#
# === Iteration 25 | eta=0.0385 ===
# BR vs current avg (candidate perspective): {'A': 1119, 'B': 881, 'total': 2000}
# Logged BR=B25, new AVG=A26
#
# === Iteration 26 | eta=0.0370 ===
# BR vs current avg (candidate perspective): {'A': 1082, 'B': 918, 'total': 2000}
# Logged BR=B26, new AVG=A27
#
# === Iteration 27 | eta=0.0357 ===
# BR vs current avg (candidate perspective): {'A': 1050, 'B': 950, 'total': 2000}
# Logged BR=B27, new AVG=A28
#
# === Iteration 28 | eta=0.0345 ===
# BR vs current avg (candidate perspective): {'A': 1078, 'B': 922, 'total': 2000}
# Logged BR=B28, new AVG=A29
#
# === Iteration 29 | eta=0.0333 ===
# BR vs current avg (candidate perspective): {'A': 1097, 'B': 903, 'total': 2000}
# Logged BR=B29, new AVG=A30
#
# === Iteration 30 | eta=0.0323 ===
# BR vs current avg (candidate perspective): {'A': 1077, 'B': 923, 'total': 2000}
# Logged BR=B30, new AVG=A31
#
# === Iteration 31 | eta=0.0312 ===
# BR vs current avg (candidate perspective): {'A': 1081, 'B': 919, 'total': 2000}
# Logged BR=B31, new AVG=A32
#
# === Iteration 32 | eta=0.0303 ===
# BR vs current avg (candidate perspective): {'A': 1096, 'B': 904, 'total': 2000}
# Logged BR=B32, new AVG=A33
#
# === Iteration 33 | eta=0.0294 ===
# BR vs current avg (candidate perspective): {'A': 1125, 'B': 875, 'total': 2000}
# Logged BR=B33, new AVG=A34
#
# === Iteration 34 | eta=0.0286 ===
# BR vs current avg (candidate perspective): {'A': 1077, 'B': 923, 'total': 2000}
# Logged BR=B34, new AVG=A35
#
# === Iteration 35 | eta=0.0278 ===
# BR vs current avg (candidate perspective): {'A': 1040, 'B': 960, 'total': 2000}
# Logged BR=B35, new AVG=A36
#
# === Iteration 36 | eta=0.0270 ===
# BR vs current avg (candidate perspective): {'A': 1075, 'B': 925, 'total': 2000}
# Logged BR=B36, new AVG=A37
#
# === Iteration 37 | eta=0.0263 ===
# BR vs current avg (candidate perspective): {'A': 1089, 'B': 911, 'total': 2000}
# Logged BR=B37, new AVG=A38
#
# === Iteration 38 | eta=0.0256 ===
# BR vs current avg (candidate perspective): {'A': 1074, 'B': 926, 'total': 2000}
# Logged BR=B38, new AVG=A39
#
# === Iteration 39 | eta=0.0250 ===
# BR vs current avg (candidate perspective): {'A': 1073, 'B': 927, 'total': 2000}
# Logged BR=B39, new AVG=A40
#
# === Iteration 40 | eta=0.0244 ===
# BR vs current avg (candidate perspective): {'A': 1049, 'B': 951, 'total': 2000}
# Logged BR=B40, new AVG=A41
#
# === Iteration 41 | eta=0.0238 ===
# BR vs current avg (candidate perspective): {'A': 1069, 'B': 931, 'total': 2000}
# Logged BR=B41, new AVG=A42
#
# === Iteration 42 | eta=0.0233 ===
# BR vs current avg (candidate perspective): {'A': 1069, 'B': 931, 'total': 2000}
# Logged BR=B42, new AVG=A43
#
# === Iteration 43 | eta=0.0227 ===
# BR vs current avg (candidate perspective): {'A': 1059, 'B': 941, 'total': 2000}
# Logged BR=B43, new AVG=A44
#
# === Iteration 44 | eta=0.0222 ===
# BR vs current avg (candidate perspective): {'A': 1066, 'B': 934, 'total': 2000}
# Logged BR=B44, new AVG=A45
#
# === Iteration 45 | eta=0.0217 ===
# BR vs current avg (candidate perspective): {'A': 1066, 'B': 934, 'total': 2000}
# Logged BR=B45, new AVG=A46
#
# === Iteration 46 | eta=0.0213 ===
# BR vs current avg (candidate perspective): {'A': 1034, 'B': 966, 'total': 2000}
# Logged BR=B46, new AVG=A47
#
# === Iteration 47 | eta=0.0208 ===
# BR vs current avg (candidate perspective): {'A': 1041, 'B': 959, 'total': 2000}
# Logged BR=B47, new AVG=A48
#
# === Iteration 48 | eta=0.0204 ===
# BR vs current avg (candidate perspective): {'A': 1033, 'B': 967, 'total': 2000}
# Logged BR=B48, new AVG=A49
#
# === Iteration 49 | eta=0.0200 ===
# BR vs current avg (candidate perspective): {'A': 1053, 'B': 947, 'total': 2000}
# Logged BR=B49, new AVG=A50
#
# Done. Latest average policy id: A50

# %%
from liars_poker.simple_api import load_policy, _load_spec

# pick an id, e.g. "A3" or "B1"
pid = "A50"
run_dir = '/root/liars_poker/artifacts/runs/run_20251012_201636_42'


policy = load_policy(run_dir, pid)

# %%
play_vs_bot(spec, policy, my_cards=[5], bot_cards=[2], start='me')
# Out:
# Your hand: (5,)
# To play: You
# Last claim: None
# Legal: ['RankHigh:1', 'RankHigh:2', 'RankHigh:3', 'Pair:1', 'Pair:2', 'Pair:3']
# Error: Unrecognized action string:
# To play: You
# Last claim: None
# Legal: ['RankHigh:1', 'RankHigh:2', 'RankHigh:3', 'Pair:1', 'Pair:2', 'Pair:3']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 play_vs_bot(spec, policy, my_cards=[5], bot_cards=[2], start='me')
#
# File ~/liars_poker/liars_poker/simple_api.py:254, in play_vs_bot(spec, policy, my_cards, bot_cards, start)
#     252 print("Last claim:", last)
#     253 print("Legal:", [env.render_action(a) for a in obs["legal_actions"]])
# --> 254 move = input("Your action: ").strip()
#     255 try:
#     256     action = env.parse_action(move, obs["legal_actions"])
#
# File /venv/main/lib/python3.12/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File /venv/main/lib/python3.12/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
