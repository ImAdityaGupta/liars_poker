# %%
import os, sys

# find repo root (looks for liars_poker/ or pyproject.toml)
def find_repo_root(start_dir: str) -> str:
    cur = os.path.abspath(start_dir)
    for _ in range(6):
        if os.path.isdir(os.path.join(cur, "liars_poker")) or os.path.exists(os.path.join(cur, "pyproject.toml")):
            return cur
        parent = os.path.dirname(cur)
        if parent == cur:
            break
        cur = parent
    return os.path.abspath(os.path.join(start_dir, "..", ".."))

NB_DIR = os.getcwd()
REPO_ROOT = find_repo_root(NB_DIR)
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

ARTIFACTS_ROOT = os.path.join(REPO_ROOT, "artifacts")
os.makedirs(ARTIFACTS_ROOT, exist_ok=True)

print("repo root   :", REPO_ROOT)
print("artifacts   :", ARTIFACTS_ROOT)
# Out:
# repo root   : /root/liars_poker
# artifacts   : /root/liars_poker/artifacts

# %%
import scipy.stats as stats
import random
from pprint import pprint

from liars_poker import (
    GameSpec, Env, InfoSet, Rules,
    Policy, TabularPolicy, CommitOnceMixture, RandomPolicy,
    eval_both_seats
)

from liars_poker.algo.br_exact import best_response_exact
from typing import List, Tuple

SEED = 42
random.seed(SEED)

# small game; P1 always starts by design
spec = GameSpec(ranks=7, suits=2, hand_size=1, claim_kinds=("RankHigh", "Pair"), suit_symmetry=True)
rules = Rules(spec)

# %%
def flatten_commit_once(policy: Policy) -> List[Tuple[Policy, float]]:
    if isinstance(policy, CommitOnceMixture):
        return list(zip(policy.policies, policy.weights))
    return [(policy, 1.0)]

def mix_policies(base_policy: Policy, br_policy: Policy, eta: float, rng: random.Random | None = None) -> CommitOnceMixture:
    base_components = flatten_commit_once(base_policy)
    br_components = flatten_commit_once(br_policy)

    combined_policies: List[Policy] = []
    combined_weights: List[float] = []

    for policy, weight in base_components:
        scaled = (1.0 - eta) * weight
        combined_policies.append(policy)
        combined_weights.append(scaled)

    for policy, weight in br_components:
        scaled = eta * weight
        combined_policies.append(policy)
        combined_weights.append(scaled)

    mixed_policy = CommitOnceMixture(combined_policies, combined_weights, rng=rng)
    mixed_policy.bind_rules(base_policy._rules)

    return mixed_policy

# %%
a0 = RandomPolicy()
a0.bind_rules(rules=rules)

# %%
all_averages = [a0]
all_brs = []

curr_av = a0

# %%
import math 


last_exploitablity = 1

for i in range(1000):
    print(i)

    eta = 1 / (i+2)

    #b_i = efficient_best_response_mc_v3(spec=spec, opponent=curr_av, episodes=episodes, epsilon=0.1, min_visits_per_action=0, annotate='none', seed=i)
    b_i, br_computer = best_response_exact(spec=spec, policy=curr_av)
    p_first, p_second = br_computer.exploitability()
    predicted = 0.5 * (p_first + p_second)

    eval_results = eval_both_seats(spec, b_i, curr_av, episodes=10_000, seed=random.randint(1,1000))
    observed_wins = eval_results['A']
    total_games = eval_results['total']
    observed_rate = observed_wins / total_games

    expected_successes = total_games * predicted
    expected_failures = total_games * (1 - predicted)
    observed_failures = total_games - observed_wins

    chi2_stat = 0.0
    if expected_successes > 0 and expected_failures > 0:
        chi2_stat = ((observed_wins - expected_successes) ** 2) / expected_successes + ((observed_failures - expected_failures) ** 2) / expected_failures
    p_value = 1 - stats.chi2.cdf(chi2_stat, 1)


    all_brs.append(b_i)

    last_exploitablity = observed_rate
    print(f"Predicted exploitability: avg={predicted:.4f} (first={p_first:.4f}, second={p_second:.4f})")
    print(f"Sampled exploitability: avg={observed_rate:.4f}, chi2 p-value={p_value:.4g}")
    print()

    curr_av = mix_policies(curr_av, b_i, eta)
    all_averages.append(curr_av)
# Out:
# 0
# Predicted exploitability: avg=0.9572 (first=0.9615, second=0.9529)
# Sampled exploitability: avg=0.9558, chi2 p-value=0.4848
#
# 1
# Predicted exploitability: avg=0.8692 (first=0.8888, second=0.8497)
# Sampled exploitability: avg=0.8723, chi2 p-value=0.3654
#
# 2
# Predicted exploitability: avg=0.8283 (first=0.8746, second=0.7819)
# Sampled exploitability: avg=0.8310, chi2 p-value=0.4669
#
# 3
# Predicted exploitability: avg=0.7743 (first=0.8001, second=0.7485)
# Sampled exploitability: avg=0.7763, chi2 p-value=0.6308
#
# 4
# Predicted exploitability: avg=0.7715 (first=0.7895, second=0.7536)
# Sampled exploitability: avg=0.7756, chi2 p-value=0.3343
#
# 5
# Predicted exploitability: avg=0.7762 (first=0.7944, second=0.7580)
# Sampled exploitability: avg=0.7819, chi2 p-value=0.1719
#
# 6
# Predicted exploitability: avg=0.7728 (first=0.8049, second=0.7407)
# Sampled exploitability: avg=0.7684, chi2 p-value=0.292
#
# 7
# Predicted exploitability: avg=0.7721 (first=0.7889, second=0.7553)
# Sampled exploitability: avg=0.7780, chi2 p-value=0.1571
#
# 8
# Predicted exploitability: avg=0.7710 (first=0.7772, second=0.7649)
# Sampled exploitability: avg=0.7784, chi2 p-value=0.07883
#
# 9
# Predicted exploitability: avg=0.7753 (first=0.7755, second=0.7752)
# Sampled exploitability: avg=0.7662, chi2 p-value=0.02859
#
# 10
# Predicted exploitability: avg=0.7669 (first=0.7819, second=0.7518)
# Sampled exploitability: avg=0.7662, chi2 p-value=0.8743
#
# 11
# Predicted exploitability: avg=0.7601 (first=0.7607, second=0.7594)
# Sampled exploitability: avg=0.7598, chi2 p-value=0.9469
#
# 12
# Predicted exploitability: avg=0.7521 (first=0.7593, second=0.7449)
# Sampled exploitability: avg=0.7514, chi2 p-value=0.8775
#
# 13
# Predicted exploitability: avg=0.7474 (first=0.7584, second=0.7364)
# Sampled exploitability: avg=0.7466, chi2 p-value=0.849
#
# 14
# Predicted exploitability: avg=0.7408 (first=0.7438, second=0.7379)
# Sampled exploitability: avg=0.7467, chi2 p-value=0.1802
#
# 15
# Predicted exploitability: avg=0.7388 (first=0.7440, second=0.7337)
# Sampled exploitability: avg=0.7385, chi2 p-value=0.943
#
# 16
# Predicted exploitability: avg=0.7406 (first=0.7435, second=0.7378)
# Sampled exploitability: avg=0.7449, chi2 p-value=0.3291
#
# 17
# Predicted exploitability: avg=0.7397 (first=0.7431, second=0.7364)
# Sampled exploitability: avg=0.7351, chi2 p-value=0.2908
#
# 18
# Predicted exploitability: avg=0.7361 (first=0.7346, second=0.7375)
# Sampled exploitability: avg=0.7308, chi2 p-value=0.2308
#
# 19
# Predicted exploitability: avg=0.7351 (first=0.7348, second=0.7353)
# Sampled exploitability: avg=0.7279, chi2 p-value=0.1046
#
# 20
# Predicted exploitability: avg=0.7293 (first=0.7234, second=0.7353)
# Sampled exploitability: avg=0.7320, chi2 p-value=0.5502
#
# 21
# Predicted exploitability: avg=0.7247 (first=0.7260, second=0.7233)
# Sampled exploitability: avg=0.7182, chi2 p-value=0.1475
#
# 22
# Predicted exploitability: avg=0.7173 (first=0.7211, second=0.7135)
# Sampled exploitability: avg=0.7128, chi2 p-value=0.3158
#
# 23
# Predicted exploitability: avg=0.7097 (first=0.7149, second=0.7045)
# Sampled exploitability: avg=0.7045, chi2 p-value=0.2539
#
# 24
# Predicted exploitability: avg=0.7050 (first=0.7066, second=0.7035)
# Sampled exploitability: avg=0.7001, chi2 p-value=0.2779
#
# 25
# Predicted exploitability: avg=0.7005 (first=0.7030, second=0.6980)
# Sampled exploitability: avg=0.6938, chi2 p-value=0.1419
#
# 26
# Predicted exploitability: avg=0.6956 (first=0.6974, second=0.6937)
# Sampled exploitability: avg=0.6939, chi2 p-value=0.7193
#
# 27
# Predicted exploitability: avg=0.6888 (first=0.6945, second=0.6831)
# Sampled exploitability: avg=0.6803, chi2 p-value=0.067
#
# 28
# Predicted exploitability: avg=0.6862 (first=0.6910, second=0.6814)
# Sampled exploitability: avg=0.6903, chi2 p-value=0.3779
#
# 29
# Predicted exploitability: avg=0.6821 (first=0.6828, second=0.6814)
# Sampled exploitability: avg=0.6730, chi2 p-value=0.05006
#
# 30
# Predicted exploitability: avg=0.6768 (first=0.6807, second=0.6729)
# Sampled exploitability: avg=0.6783, chi2 p-value=0.7484
#
# 31
# Predicted exploitability: avg=0.6725 (first=0.6773, second=0.6677)
# Sampled exploitability: avg=0.6701, chi2 p-value=0.6114
#
# 32
# Predicted exploitability: avg=0.6681 (first=0.6731, second=0.6631)
# Sampled exploitability: avg=0.6683, chi2 p-value=0.9599
#
# 33
# Predicted exploitability: avg=0.6638 (first=0.6681, second=0.6595)
# Sampled exploitability: avg=0.6675, chi2 p-value=0.4313
#
# 34
# Predicted exploitability: avg=0.6594 (first=0.6631, second=0.6557)
# Sampled exploitability: avg=0.6623, chi2 p-value=0.5429
#
# 35
# Predicted exploitability: avg=0.6559 (first=0.6597, second=0.6522)
# Sampled exploitability: avg=0.6527, chi2 p-value=0.497
#
# 36
# Predicted exploitability: avg=0.6520 (first=0.6564, second=0.6476)
# Sampled exploitability: avg=0.6554, chi2 p-value=0.4765
#
# 37
# Predicted exploitability: avg=0.6485 (first=0.6536, second=0.6433)
# Sampled exploitability: avg=0.6434, chi2 p-value=0.2883
#
# 38
# Predicted exploitability: avg=0.6456 (first=0.6515, second=0.6398)
# Sampled exploitability: avg=0.6511, chi2 p-value=0.2538
#
# 39
# Predicted exploitability: avg=0.6420 (first=0.6476, second=0.6364)
# Sampled exploitability: avg=0.6411, chi2 p-value=0.8477
#
# 40
# Predicted exploitability: avg=0.6386 (first=0.6433, second=0.6338)
# Sampled exploitability: avg=0.6305, chi2 p-value=0.09353
#
# 41
# Predicted exploitability: avg=0.6358 (first=0.6395, second=0.6320)
# Sampled exploitability: avg=0.6325, chi2 p-value=0.497
#
# 42
# Predicted exploitability: avg=0.6328 (first=0.6361, second=0.6296)
# Sampled exploitability: avg=0.6288, chi2 p-value=0.4025
#
# 43
# Predicted exploitability: avg=0.6298 (first=0.6338, second=0.6258)
# Sampled exploitability: avg=0.6265, chi2 p-value=0.4922
#
# 44
# Predicted exploitability: avg=0.6272 (first=0.6317, second=0.6226)
# Sampled exploitability: avg=0.6350, chi2 p-value=0.1058
#
# 45
# Predicted exploitability: avg=0.6245 (first=0.6287, second=0.6203)
# Sampled exploitability: avg=0.6185, chi2 p-value=0.2128
#
# 46
# Predicted exploitability: avg=0.6219 (first=0.6257, second=0.6181)
# Sampled exploitability: avg=0.6235, chi2 p-value=0.7388
#
# 47
# Predicted exploitability: avg=0.6194 (first=0.6227, second=0.6160)
# Sampled exploitability: avg=0.6121, chi2 p-value=0.1345
#
# 48
# Predicted exploitability: avg=0.6169 (first=0.6206, second=0.6133)
# Sampled exploitability: avg=0.6146, chi2 p-value=0.6318
#
# 49
# Predicted exploitability: avg=0.6146 (first=0.6185, second=0.6107)
# Sampled exploitability: avg=0.6169, chi2 p-value=0.6352
#
# 50
# Predicted exploitability: avg=0.6123 (first=0.6165, second=0.6082)
# Sampled exploitability: avg=0.6120, chi2 p-value=0.9437
#
# 51
# Predicted exploitability: avg=0.6102 (first=0.6146, second=0.6058)
# Sampled exploitability: avg=0.6057, chi2 p-value=0.3579
#
# 52
# Predicted exploitability: avg=0.6081 (first=0.6127, second=0.6035)
# Sampled exploitability: avg=0.6088, chi2 p-value=0.8868
#
# 53
# Predicted exploitability: avg=0.6061 (first=0.6109, second=0.6013)
# Sampled exploitability: avg=0.6070, chi2 p-value=0.8543
#
# 54
# Predicted exploitability: avg=0.6042 (first=0.6092, second=0.5991)
# Sampled exploitability: avg=0.6017, chi2 p-value=0.613
#
# 55
# Predicted exploitability: avg=0.6023 (first=0.6076, second=0.5971)
# Sampled exploitability: avg=0.6072, chi2 p-value=0.3181
#
# 56
# Predicted exploitability: avg=0.6006 (first=0.6060, second=0.5953)
# Sampled exploitability: avg=0.6014, chi2 p-value=0.8723
#
# 57
# Predicted exploitability: avg=0.5989 (first=0.6042, second=0.5935)
# Sampled exploitability: avg=0.5965, chi2 p-value=0.6276
#
# 58
# Predicted exploitability: avg=0.5972 (first=0.6026, second=0.5918)
# Sampled exploitability: avg=0.5940, chi2 p-value=0.5138
#
# 59
# Predicted exploitability: avg=0.5956 (first=0.6009, second=0.5902)
# Sampled exploitability: avg=0.5975, chi2 p-value=0.6959
#
# 60
# Predicted exploitability: avg=0.5940 (first=0.5994, second=0.5887)
# Sampled exploitability: avg=0.5923, chi2 p-value=0.7269
#
# 61
# Predicted exploitability: avg=0.5925 (first=0.5979, second=0.5871)
# Sampled exploitability: avg=0.5876, chi2 p-value=0.3188
#
# 62
# Predicted exploitability: avg=0.5910 (first=0.5964, second=0.5857)
# Sampled exploitability: avg=0.5931, chi2 p-value=0.6738
#
# 63
# Predicted exploitability: avg=0.5896 (first=0.5950, second=0.5842)
# Sampled exploitability: avg=0.5882, chi2 p-value=0.7747
#
# 64
# Predicted exploitability: avg=0.5882 (first=0.5936, second=0.5829)
# Sampled exploitability: avg=0.5955, chi2 p-value=0.1396
#
# 65
# Predicted exploitability: avg=0.5870 (first=0.5924, second=0.5815)
# Sampled exploitability: avg=0.5808, chi2 p-value=0.2099
#
# 66
# Predicted exploitability: avg=0.5858 (first=0.5913, second=0.5802)
# Sampled exploitability: avg=0.5842, chi2 p-value=0.7526
#
# 67
# Predicted exploitability: avg=0.5845 (first=0.5900, second=0.5790)
# Sampled exploitability: avg=0.5879, chi2 p-value=0.4891
#
# 68
# Predicted exploitability: avg=0.5835 (first=0.5892, second=0.5777)
# Sampled exploitability: avg=0.5762, chi2 p-value=0.1412
#
# 69
# Predicted exploitability: avg=0.5830 (first=0.5892, second=0.5767)
# Sampled exploitability: avg=0.5836, chi2 p-value=0.8977
#
# 70
# Predicted exploitability: avg=0.5819 (first=0.5880, second=0.5757)
# Sampled exploitability: avg=0.5729, chi2 p-value=0.06928
#
# 71
# Predicted exploitability: avg=0.5807 (first=0.5869, second=0.5746)
# Sampled exploitability: avg=0.5740, chi2 p-value=0.173
#
# 72
# Predicted exploitability: avg=0.5797 (first=0.5858, second=0.5736)
# Sampled exploitability: avg=0.5763, chi2 p-value=0.4918
#
# 73
# Predicted exploitability: avg=0.5786 (first=0.5844, second=0.5728)
# Sampled exploitability: avg=0.5804, chi2 p-value=0.7179
#
# 74
# Predicted exploitability: avg=0.5776 (first=0.5830, second=0.5722)
# Sampled exploitability: avg=0.5809, chi2 p-value=0.5087
#
# 75
# Predicted exploitability: avg=0.5766 (first=0.5816, second=0.5716)
# Sampled exploitability: avg=0.5750, chi2 p-value=0.7439
#
# 76
# Predicted exploitability: avg=0.5757 (first=0.5804, second=0.5711)
# Sampled exploitability: avg=0.5728, chi2 p-value=0.5511
#
# 77
# Predicted exploitability: avg=0.5749 (first=0.5795, second=0.5702)
# Sampled exploitability: avg=0.5655, chi2 p-value=0.0584
#
# 78
# Predicted exploitability: avg=0.5739 (first=0.5785, second=0.5693)
# Sampled exploitability: avg=0.5700, chi2 p-value=0.4285
#
# 79
# Predicted exploitability: avg=0.5730 (first=0.5773, second=0.5686)
# Sampled exploitability: avg=0.5772, chi2 p-value=0.3948
#
# 80
# Predicted exploitability: avg=0.5721 (first=0.5763, second=0.5680)
# Sampled exploitability: avg=0.5751, chi2 p-value=0.5489
#
# 81
# Predicted exploitability: avg=0.5713 (first=0.5753, second=0.5672)
# Sampled exploitability: avg=0.5658, chi2 p-value=0.2704
#
# 82
# Predicted exploitability: avg=0.5704 (first=0.5743, second=0.5665)
# Sampled exploitability: avg=0.5718, chi2 p-value=0.7767
#
# 83
# Predicted exploitability: avg=0.5696 (first=0.5734, second=0.5658)
# Sampled exploitability: avg=0.5682, chi2 p-value=0.7839
#
# 84
# Predicted exploitability: avg=0.5688 (first=0.5725, second=0.5651)
# Sampled exploitability: avg=0.5608, chi2 p-value=0.1083
#
# 85
# Predicted exploitability: avg=0.5680 (first=0.5717, second=0.5642)
# Sampled exploitability: avg=0.5659, chi2 p-value=0.6784
#
# 86
# Predicted exploitability: avg=0.5672 (first=0.5709, second=0.5634)
# Sampled exploitability: avg=0.5709, chi2 p-value=0.4519
#
# 87
# Predicted exploitability: avg=0.5664 (first=0.5702, second=0.5626)
# Sampled exploitability: avg=0.5668, chi2 p-value=0.9372
#
# 88
# Predicted exploitability: avg=0.5657 (first=0.5694, second=0.5619)
# Sampled exploitability: avg=0.5745, chi2 p-value=0.07463
#
# 89
# Predicted exploitability: avg=0.5652 (first=0.5687, second=0.5616)
# Sampled exploitability: avg=0.5635, chi2 p-value=0.7367
#
# 90
# Predicted exploitability: avg=0.5646 (first=0.5676, second=0.5616)
# Sampled exploitability: avg=0.5679, chi2 p-value=0.5014
#
# 91
# Predicted exploitability: avg=0.5640 (first=0.5665, second=0.5616)
# Sampled exploitability: avg=0.5686, chi2 p-value=0.3568
#
# 92
# Predicted exploitability: avg=0.5633 (first=0.5657, second=0.5610)
# Sampled exploitability: avg=0.5640, chi2 p-value=0.8945
#
# 93
# Predicted exploitability: avg=0.5627 (first=0.5650, second=0.5604)
# Sampled exploitability: avg=0.5632, chi2 p-value=0.9147
#
# 94
# Predicted exploitability: avg=0.5622 (first=0.5646, second=0.5599)
# Sampled exploitability: avg=0.5681, chi2 p-value=0.2383
#
# 95
# Predicted exploitability: avg=0.5616 (first=0.5643, second=0.5589)
# Sampled exploitability: avg=0.5552, chi2 p-value=0.197
#
# 96
# Predicted exploitability: avg=0.5610 (first=0.5641, second=0.5579)
# Sampled exploitability: avg=0.5608, chi2 p-value=0.9725
#
# 97
# Predicted exploitability: avg=0.5604 (first=0.5636, second=0.5572)
# Sampled exploitability: avg=0.5627, chi2 p-value=0.6372
#
# 98
# Predicted exploitability: avg=0.5597 (first=0.5626, second=0.5569)
# Sampled exploitability: avg=0.5538, chi2 p-value=0.2307
#
# 99
# Predicted exploitability: avg=0.5592 (first=0.5617, second=0.5566)
# Sampled exploitability: avg=0.5585, chi2 p-value=0.8955
#
# 100
# Predicted exploitability: avg=0.5586 (first=0.5609, second=0.5563)
# Sampled exploitability: avg=0.5582, chi2 p-value=0.9412
#
# 101
# Predicted exploitability: avg=0.5580 (first=0.5600, second=0.5560)
# Sampled exploitability: avg=0.5584, chi2 p-value=0.9346
#
# 102
# Predicted exploitability: avg=0.5574 (first=0.5591, second=0.5557)
# Sampled exploitability: avg=0.5620, chi2 p-value=0.3575
#
# 103
# Predicted exploitability: avg=0.5569 (first=0.5583, second=0.5554)
# Sampled exploitability: avg=0.5568, chi2 p-value=0.9876
#
# 104
# Predicted exploitability: avg=0.5563 (first=0.5575, second=0.5552)
# Sampled exploitability: avg=0.5502, chi2 p-value=0.2169
#
# 105
# Predicted exploitability: avg=0.5558 (first=0.5567, second=0.5549)
# Sampled exploitability: avg=0.5545, chi2 p-value=0.793
#
# 106
# Predicted exploitability: avg=0.5553 (first=0.5559, second=0.5547)
# Sampled exploitability: avg=0.5556, chi2 p-value=0.949
#
# 107
# Predicted exploitability: avg=0.5548 (first=0.5551, second=0.5544)
# Sampled exploitability: avg=0.5599, chi2 p-value=0.302
#
# 108
# Predicted exploitability: avg=0.5543 (first=0.5544, second=0.5542)
# Sampled exploitability: avg=0.5532, chi2 p-value=0.8299
#
# 109
# Predicted exploitability: avg=0.5538 (first=0.5536, second=0.5539)
# Sampled exploitability: avg=0.5439, chi2 p-value=0.04698
#
# 110
# Predicted exploitability: avg=0.5533 (first=0.5529, second=0.5537)
# Sampled exploitability: avg=0.5432, chi2 p-value=0.0424
#
# 111
# Predicted exploitability: avg=0.5528 (first=0.5522, second=0.5534)
# Sampled exploitability: avg=0.5511, chi2 p-value=0.7302
#
# 112
# Predicted exploitability: avg=0.5523 (first=0.5515, second=0.5532)
# Sampled exploitability: avg=0.5483, chi2 p-value=0.4157
#
# 113
# Predicted exploitability: avg=0.5519 (first=0.5508, second=0.5530)
# Sampled exploitability: avg=0.5550, chi2 p-value=0.5314
#
# 114
# Predicted exploitability: avg=0.5515 (first=0.5502, second=0.5528)
# Sampled exploitability: avg=0.5628, chi2 p-value=0.02278
#
# 115
# Predicted exploitability: avg=0.5510 (first=0.5496, second=0.5525)
# Sampled exploitability: avg=0.5439, chi2 p-value=0.1516
#
# 116
# Predicted exploitability: avg=0.5506 (first=0.5490, second=0.5521)
# Sampled exploitability: avg=0.5515, chi2 p-value=0.8557
#
# 117
# Predicted exploitability: avg=0.5502 (first=0.5485, second=0.5518)
# Sampled exploitability: avg=0.5553, chi2 p-value=0.3021
#
# 118
# Predicted exploitability: avg=0.5497 (first=0.5479, second=0.5515)
# Sampled exploitability: avg=0.5537, chi2 p-value=0.4267
#
# 119
# Predicted exploitability: avg=0.5494 (first=0.5474, second=0.5513)
# Sampled exploitability: avg=0.5498, chi2 p-value=0.9321
#
# 120
# Predicted exploitability: avg=0.5490 (first=0.5468, second=0.5511)
# Sampled exploitability: avg=0.5475, chi2 p-value=0.768
#
# 121
# Predicted exploitability: avg=0.5486 (first=0.5462, second=0.5510)
# Sampled exploitability: avg=0.5480, chi2 p-value=0.9094
#
# 122
# Predicted exploitability: avg=0.5482 (first=0.5456, second=0.5508)
# Sampled exploitability: avg=0.5513, chi2 p-value=0.5296
#
# 123
# Predicted exploitability: avg=0.5478 (first=0.5450, second=0.5506)
# Sampled exploitability: avg=0.5486, chi2 p-value=0.8696
#
# 124
# Predicted exploitability: avg=0.5475 (first=0.5445, second=0.5504)
# Sampled exploitability: avg=0.5493, chi2 p-value=0.7108
#
# 125
# Predicted exploitability: avg=0.5471 (first=0.5441, second=0.5501)
# Sampled exploitability: avg=0.5486, chi2 p-value=0.7665
#
# 126
# Predicted exploitability: avg=0.5468 (first=0.5436, second=0.5499)
# Sampled exploitability: avg=0.5572, chi2 p-value=0.03581
#
# 127
# Predicted exploitability: avg=0.5464 (first=0.5430, second=0.5498)
# Sampled exploitability: avg=0.5495, chi2 p-value=0.5316
#
# 128
# Predicted exploitability: avg=0.5460 (first=0.5425, second=0.5496)
# Sampled exploitability: avg=0.5414, chi2 p-value=0.3522
#
# 129
# Predicted exploitability: avg=0.5457 (first=0.5420, second=0.5493)
# Sampled exploitability: avg=0.5479, chi2 p-value=0.6553
#
# 130
# Predicted exploitability: avg=0.5453 (first=0.5416, second=0.5491)
# Sampled exploitability: avg=0.5378, chi2 p-value=0.1304
#
# 131
# Predicted exploitability: avg=0.5450 (first=0.5412, second=0.5488)
# Sampled exploitability: avg=0.5510, chi2 p-value=0.2273
#
# 132
# Predicted exploitability: avg=0.5446 (first=0.5409, second=0.5484)
# Sampled exploitability: avg=0.5383, chi2 p-value=0.2023
#
# 133
# Predicted exploitability: avg=0.5443 (first=0.5405, second=0.5481)
# Sampled exploitability: avg=0.5417, chi2 p-value=0.5994
#
# 134
# Predicted exploitability: avg=0.5441 (first=0.5402, second=0.5481)
# Sampled exploitability: avg=0.5448, chi2 p-value=0.8957
#
# 135
# Predicted exploitability: avg=0.5440 (first=0.5394, second=0.5487)
# Sampled exploitability: avg=0.5477, chi2 p-value=0.461
#
# 136
# Predicted exploitability: avg=0.5437 (first=0.5386, second=0.5488)
# Sampled exploitability: avg=0.5478, chi2 p-value=0.4112
#
# 137
# Predicted exploitability: avg=0.5435 (first=0.5380, second=0.5490)
# Sampled exploitability: avg=0.5420, chi2 p-value=0.7621
#
# 138
# Predicted exploitability: avg=0.5432 (first=0.5375, second=0.5489)
# Sampled exploitability: avg=0.5433, chi2 p-value=0.9887
#
# 139
# Predicted exploitability: avg=0.5430 (first=0.5372, second=0.5487)
# Sampled exploitability: avg=0.5448, chi2 p-value=0.7106
#
# 140
# Predicted exploitability: avg=0.5426 (first=0.5371, second=0.5482)
# Sampled exploitability: avg=0.5398, chi2 p-value=0.5677
#
# 141
# Predicted exploitability: avg=0.5423 (first=0.5369, second=0.5478)
# Sampled exploitability: avg=0.5362, chi2 p-value=0.2173
#
# 142
# Predicted exploitability: avg=0.5421 (first=0.5368, second=0.5473)
# Sampled exploitability: avg=0.5503, chi2 p-value=0.09776
#
# 143
# Predicted exploitability: avg=0.5418 (first=0.5366, second=0.5469)
# Sampled exploitability: avg=0.5431, chi2 p-value=0.7877
#
# 144
# Predicted exploitability: avg=0.5415 (first=0.5365, second=0.5465)
# Sampled exploitability: avg=0.5336, chi2 p-value=0.1142
#
# 145
# Predicted exploitability: avg=0.5412 (first=0.5363, second=0.5460)
# Sampled exploitability: avg=0.5428, chi2 p-value=0.7466
#
# 146
# Predicted exploitability: avg=0.5409 (first=0.5361, second=0.5458)
# Sampled exploitability: avg=0.5306, chi2 p-value=0.03856
#
# 147
# Predicted exploitability: avg=0.5406 (first=0.5358, second=0.5455)
# Sampled exploitability: avg=0.5365, chi2 p-value=0.4069
#
# 148
# Predicted exploitability: avg=0.5404 (first=0.5355, second=0.5452)
# Sampled exploitability: avg=0.5380, chi2 p-value=0.6358
#
# 149
# Predicted exploitability: avg=0.5401 (first=0.5352, second=0.5450)
# Sampled exploitability: avg=0.5414, chi2 p-value=0.7933
#
# 150
# Predicted exploitability: avg=0.5398 (first=0.5348, second=0.5448)
# Sampled exploitability: avg=0.5369, chi2 p-value=0.5568
#
# 151
# Predicted exploitability: avg=0.5396 (first=0.5344, second=0.5447)
# Sampled exploitability: avg=0.5393, chi2 p-value=0.9573
#
# 152
# Predicted exploitability: avg=0.5393 (first=0.5340, second=0.5446)
# Sampled exploitability: avg=0.5382, chi2 p-value=0.8241
#
# 153
# Predicted exploitability: avg=0.5391 (first=0.5336, second=0.5445)
# Sampled exploitability: avg=0.5469, chi2 p-value=0.1154
#
# 154
# Predicted exploitability: avg=0.5388 (first=0.5332, second=0.5444)
# Sampled exploitability: avg=0.5406, chi2 p-value=0.7182
#
# 155
# Predicted exploitability: avg=0.5386 (first=0.5328, second=0.5443)
# Sampled exploitability: avg=0.5377, chi2 p-value=0.8643
#
# 156
# Predicted exploitability: avg=0.5383 (first=0.5324, second=0.5442)
# Sampled exploitability: avg=0.5387, chi2 p-value=0.9371
#
# 157
# Predicted exploitability: avg=0.5381 (first=0.5321, second=0.5441)
# Sampled exploitability: avg=0.5340, chi2 p-value=0.415
#
# 158
# Predicted exploitability: avg=0.5378 (first=0.5317, second=0.5440)
# Sampled exploitability: avg=0.5358, chi2 p-value=0.6847
#
# 159
# Predicted exploitability: avg=0.5376 (first=0.5313, second=0.5439)
# Sampled exploitability: avg=0.5381, chi2 p-value=0.9183
#
# 160
# Predicted exploitability: avg=0.5374 (first=0.5309, second=0.5438)
# Sampled exploitability: avg=0.5298, chi2 p-value=0.1297
#
# 161
# Predicted exploitability: avg=0.5372 (first=0.5307, second=0.5437)
# Sampled exploitability: avg=0.5345, chi2 p-value=0.5827
#
# 162
# Predicted exploitability: avg=0.5370 (first=0.5305, second=0.5436)
# Sampled exploitability: avg=0.5349, chi2 p-value=0.672
#
# 163
# Predicted exploitability: avg=0.5368 (first=0.5302, second=0.5434)
# Sampled exploitability: avg=0.5295, chi2 p-value=0.144
#
# 164
# Predicted exploitability: avg=0.5366 (first=0.5299, second=0.5432)
# Sampled exploitability: avg=0.5379, chi2 p-value=0.7885
#
# 165
# Predicted exploitability: avg=0.5363 (first=0.5296, second=0.5431)
# Sampled exploitability: avg=0.5417, chi2 p-value=0.2826
#
# 166
# Predicted exploitability: avg=0.5361 (first=0.5293, second=0.5429)
# Sampled exploitability: avg=0.5352, chi2 p-value=0.8529
#
# 167
# Predicted exploitability: avg=0.5359 (first=0.5291, second=0.5428)
# Sampled exploitability: avg=0.5279, chi2 p-value=0.1083
#
# 168
# Predicted exploitability: avg=0.5357 (first=0.5288, second=0.5426)
# Sampled exploitability: avg=0.5413, chi2 p-value=0.2616
#
# 169
# Predicted exploitability: avg=0.5355 (first=0.5286, second=0.5424)
# Sampled exploitability: avg=0.5357, chi2 p-value=0.9666
#
# 170
# Predicted exploitability: avg=0.5353 (first=0.5284, second=0.5422)
# Sampled exploitability: avg=0.5375, chi2 p-value=0.6568
#
# 171
# Predicted exploitability: avg=0.5351 (first=0.5282, second=0.5420)
# Sampled exploitability: avg=0.5301, chi2 p-value=0.3182
#
# 172
# Predicted exploitability: avg=0.5349 (first=0.5280, second=0.5417)
# Sampled exploitability: avg=0.5299, chi2 p-value=0.3185
#
# 173
# Predicted exploitability: avg=0.5347 (first=0.5278, second=0.5415)
# Sampled exploitability: avg=0.5324, chi2 p-value=0.6482
#
# 174
# Predicted exploitability: avg=0.5345 (first=0.5276, second=0.5415)
# Sampled exploitability: avg=0.5240, chi2 p-value=0.03461
#
# 175
# Predicted exploitability: avg=0.5343 (first=0.5274, second=0.5413)
# Sampled exploitability: avg=0.5461, chi2 p-value=0.01842
#
# 176
# Predicted exploitability: avg=0.5341 (first=0.5272, second=0.5410)
# Sampled exploitability: avg=0.5375, chi2 p-value=0.5017
#
# 177
# Predicted exploitability: avg=0.5340 (first=0.5271, second=0.5408)
# Sampled exploitability: avg=0.5356, chi2 p-value=0.7419
#
# 178
# Predicted exploitability: avg=0.5338 (first=0.5269, second=0.5407)
# Sampled exploitability: avg=0.5346, chi2 p-value=0.8674
#
# 179
# Predicted exploitability: avg=0.5336 (first=0.5267, second=0.5405)
# Sampled exploitability: avg=0.5292, chi2 p-value=0.38
#
# 180
# Predicted exploitability: avg=0.5334 (first=0.5265, second=0.5403)
# Sampled exploitability: avg=0.5396, chi2 p-value=0.2135
#
# 181
# Predicted exploitability: avg=0.5333 (first=0.5263, second=0.5402)
# Sampled exploitability: avg=0.5374, chi2 p-value=0.4076
#
# 182
# Predicted exploitability: avg=0.5331 (first=0.5261, second=0.5401)
# Sampled exploitability: avg=0.5381, chi2 p-value=0.315
#
# 183
# Predicted exploitability: avg=0.5329 (first=0.5258, second=0.5400)
# Sampled exploitability: avg=0.5382, chi2 p-value=0.2887
#
# 184
# Predicted exploitability: avg=0.5327 (first=0.5255, second=0.5400)
# Sampled exploitability: avg=0.5347, chi2 p-value=0.6928
#
# 185
# Predicted exploitability: avg=0.5326 (first=0.5251, second=0.5400)
# Sampled exploitability: avg=0.5307, chi2 p-value=0.7103
#
# 186
# Predicted exploitability: avg=0.5324 (first=0.5247, second=0.5401)
# Sampled exploitability: avg=0.5369, chi2 p-value=0.3649
#
# 187
# Predicted exploitability: avg=0.5322 (first=0.5243, second=0.5401)
# Sampled exploitability: avg=0.5390, chi2 p-value=0.1734
#
# 188
# Predicted exploitability: avg=0.5321 (first=0.5240, second=0.5402)
# Sampled exploitability: avg=0.5285, chi2 p-value=0.4716
#
# 189
# Predicted exploitability: avg=0.5319 (first=0.5238, second=0.5401)
# Sampled exploitability: avg=0.5338, chi2 p-value=0.7068
#
# 190
# Predicted exploitability: avg=0.5318 (first=0.5236, second=0.5399)
# Sampled exploitability: avg=0.5303, chi2 p-value=0.7705
#
# 191
# Predicted exploitability: avg=0.5316 (first=0.5234, second=0.5398)
# Sampled exploitability: avg=0.5269, chi2 p-value=0.3472
#
# 192
# Predicted exploitability: avg=0.5314 (first=0.5232, second=0.5397)
# Sampled exploitability: avg=0.5365, chi2 p-value=0.3093
#
# 193
# Predicted exploitability: avg=0.5313 (first=0.5230, second=0.5396)
# Sampled exploitability: avg=0.5437, chi2 p-value=0.0127
#
# 194
# Predicted exploitability: avg=0.5311 (first=0.5228, second=0.5395)
# Sampled exploitability: avg=0.5287, chi2 p-value=0.63
#
# 195
# Predicted exploitability: avg=0.5309 (first=0.5226, second=0.5393)
# Sampled exploitability: avg=0.5302, chi2 p-value=0.8812
#
# 196
# Predicted exploitability: avg=0.5308 (first=0.5224, second=0.5392)
# Sampled exploitability: avg=0.5303, chi2 p-value=0.922
#
# 197
# Predicted exploitability: avg=0.5306 (first=0.5222, second=0.5391)
# Sampled exploitability: avg=0.5266, chi2 p-value=0.419
#
# 198
# Predicted exploitability: avg=0.5305 (first=0.5220, second=0.5390)
# Sampled exploitability: avg=0.5312, chi2 p-value=0.8851
#
# 199
# Predicted exploitability: avg=0.5303 (first=0.5218, second=0.5389)
# Sampled exploitability: avg=0.5341, chi2 p-value=0.4496
#
# 200
# Predicted exploitability: avg=0.5302 (first=0.5216, second=0.5388)
# Sampled exploitability: avg=0.5182, chi2 p-value=0.01642
#
# 201
# Predicted exploitability: avg=0.5300 (first=0.5214, second=0.5387)
# Sampled exploitability: avg=0.5270, chi2 p-value=0.5443
#
# 202
# Predicted exploitability: avg=0.5299 (first=0.5212, second=0.5385)
# Sampled exploitability: avg=0.5280, chi2 p-value=0.7066
#
# 203
# Predicted exploitability: avg=0.5297 (first=0.5210, second=0.5384)
# Sampled exploitability: avg=0.5231, chi2 p-value=0.1839
#
# 204
# Predicted exploitability: avg=0.5296 (first=0.5208, second=0.5383)
# Sampled exploitability: avg=0.5300, chi2 p-value=0.9341
#
# 205
# Predicted exploitability: avg=0.5294 (first=0.5207, second=0.5382)
# Sampled exploitability: avg=0.5292, chi2 p-value=0.9611
#
# 206
# Predicted exploitability: avg=0.5293 (first=0.5205, second=0.5381)
# Sampled exploitability: avg=0.5301, chi2 p-value=0.8728
#
# 207
# Predicted exploitability: avg=0.5292 (first=0.5203, second=0.5380)
# Sampled exploitability: avg=0.5291, chi2 p-value=0.9904
#
# 208
# Predicted exploitability: avg=0.5290 (first=0.5201, second=0.5379)
# Sampled exploitability: avg=0.5297, chi2 p-value=0.8918
#
# 209
# Predicted exploitability: avg=0.5289 (first=0.5200, second=0.5378)
# Sampled exploitability: avg=0.5292, chi2 p-value=0.9493
#
# 210
# Predicted exploitability: avg=0.5287 (first=0.5198, second=0.5377)
# Sampled exploitability: avg=0.5262, chi2 p-value=0.6101
#
# 211
# Predicted exploitability: avg=0.5286 (first=0.5196, second=0.5376)
# Sampled exploitability: avg=0.5318, chi2 p-value=0.5228
#
# 212
# Predicted exploitability: avg=0.5285 (first=0.5194, second=0.5375)
# Sampled exploitability: avg=0.5245, chi2 p-value=0.4258
#
# 213
# Predicted exploitability: avg=0.5283 (first=0.5193, second=0.5374)
# Sampled exploitability: avg=0.5305, chi2 p-value=0.6656
#
# 214
# Predicted exploitability: avg=0.5282 (first=0.5191, second=0.5373)
# Sampled exploitability: avg=0.5278, chi2 p-value=0.9344
#
# 215
# Predicted exploitability: avg=0.5281 (first=0.5189, second=0.5372)
# Sampled exploitability: avg=0.5330, chi2 p-value=0.3244
#
# 216
# Predicted exploitability: avg=0.5280 (first=0.5188, second=0.5371)
# Sampled exploitability: avg=0.5222, chi2 p-value=0.2481
#
# 217
# Predicted exploitability: avg=0.5278 (first=0.5187, second=0.5370)
# Sampled exploitability: avg=0.5240, chi2 p-value=0.4421
#
# 218
# Predicted exploitability: avg=0.5277 (first=0.5186, second=0.5368)
# Sampled exploitability: avg=0.5253, chi2 p-value=0.6292
#
# 219
# Predicted exploitability: avg=0.5276 (first=0.5185, second=0.5367)
# Sampled exploitability: avg=0.5258, chi2 p-value=0.7208
#
# 220
# Predicted exploitability: avg=0.5275 (first=0.5184, second=0.5366)
# Sampled exploitability: avg=0.5315, chi2 p-value=0.4184
#
# 221
# Predicted exploitability: avg=0.5273 (first=0.5183, second=0.5364)
# Sampled exploitability: avg=0.5243, chi2 p-value=0.5431
#
# 222
# Predicted exploitability: avg=0.5272 (first=0.5182, second=0.5363)
# Sampled exploitability: avg=0.5321, chi2 p-value=0.3277
#
# 223
# Predicted exploitability: avg=0.5271 (first=0.5180, second=0.5361)
# Sampled exploitability: avg=0.5229, chi2 p-value=0.4011
#
# 224
# Predicted exploitability: avg=0.5270 (first=0.5179, second=0.5360)
# Sampled exploitability: avg=0.5294, chi2 p-value=0.627
#
# 225
# Predicted exploitability: avg=0.5269 (first=0.5177, second=0.5360)
# Sampled exploitability: avg=0.5248, chi2 p-value=0.6808
#
# 226
# Predicted exploitability: avg=0.5267 (first=0.5175, second=0.5359)
# Sampled exploitability: avg=0.5299, chi2 p-value=0.5263
#
# 227
# Predicted exploitability: avg=0.5266 (first=0.5173, second=0.5359)
# Sampled exploitability: avg=0.5220, chi2 p-value=0.3525
#
# 228
# Predicted exploitability: avg=0.5265 (first=0.5171, second=0.5359)
# Sampled exploitability: avg=0.5256, chi2 p-value=0.8528
#
# 229
# Predicted exploitability: avg=0.5264 (first=0.5169, second=0.5360)
# Sampled exploitability: avg=0.5323, chi2 p-value=0.2382
#
# 230
# Predicted exploitability: avg=0.5263 (first=0.5166, second=0.5360)
# Sampled exploitability: avg=0.5394, chi2 p-value=0.008732
#
# 231
# Predicted exploitability: avg=0.5262 (first=0.5165, second=0.5359)
# Sampled exploitability: avg=0.5182, chi2 p-value=0.1094
#
# 232
# Predicted exploitability: avg=0.5261 (first=0.5164, second=0.5358)
# Sampled exploitability: avg=0.5192, chi2 p-value=0.1682
#
# 233
# Predicted exploitability: avg=0.5260 (first=0.5162, second=0.5357)
# Sampled exploitability: avg=0.5235, chi2 p-value=0.621
#
# 234
# Predicted exploitability: avg=0.5259 (first=0.5161, second=0.5356)
# Sampled exploitability: avg=0.5258, chi2 p-value=0.9907
#
# 235
# Predicted exploitability: avg=0.5257 (first=0.5159, second=0.5356)
# Sampled exploitability: avg=0.5337, chi2 p-value=0.1113
#
# 236
# Predicted exploitability: avg=0.5256 (first=0.5158, second=0.5355)
# Sampled exploitability: avg=0.5276, chi2 p-value=0.6947
#
# 237
# Predicted exploitability: avg=0.5255 (first=0.5157, second=0.5354)
# Sampled exploitability: avg=0.5222, chi2 p-value=0.5045
#
# 238
# Predicted exploitability: avg=0.5254 (first=0.5155, second=0.5353)
# Sampled exploitability: avg=0.5294, chi2 p-value=0.4261
#
# 239
# Predicted exploitability: avg=0.5253 (first=0.5154, second=0.5352)
# Sampled exploitability: avg=0.5250, chi2 p-value=0.9489
#
# 240
# Predicted exploitability: avg=0.5252 (first=0.5153, second=0.5352)
# Sampled exploitability: avg=0.5234, chi2 p-value=0.7163
#
# 241
# Predicted exploitability: avg=0.5251 (first=0.5151, second=0.5351)
# Sampled exploitability: avg=0.5258, chi2 p-value=0.8902
#
# 242
# Predicted exploitability: avg=0.5250 (first=0.5150, second=0.5350)
# Sampled exploitability: avg=0.5346, chi2 p-value=0.05474
#
# 243
# Predicted exploitability: avg=0.5249 (first=0.5149, second=0.5349)
# Sampled exploitability: avg=0.5217, chi2 p-value=0.521
#
# 244
# Predicted exploitability: avg=0.5248 (first=0.5147, second=0.5349)
# Sampled exploitability: avg=0.5299, chi2 p-value=0.3074
#
# 245
# Predicted exploitability: avg=0.5247 (first=0.5146, second=0.5348)
# Sampled exploitability: avg=0.5253, chi2 p-value=0.9047
#
# 246
# Predicted exploitability: avg=0.5246 (first=0.5145, second=0.5347)
# Sampled exploitability: avg=0.5287, chi2 p-value=0.4119
#
# 247
# Predicted exploitability: avg=0.5245 (first=0.5144, second=0.5346)
# Sampled exploitability: avg=0.5223, chi2 p-value=0.6591
#
# 248
# Predicted exploitability: avg=0.5244 (first=0.5142, second=0.5346)
# Sampled exploitability: avg=0.5258, chi2 p-value=0.7799
#
# 249
# Predicted exploitability: avg=0.5243 (first=0.5141, second=0.5345)
# Sampled exploitability: avg=0.5241, chi2 p-value=0.9669
#
# 250
# Predicted exploitability: avg=0.5242 (first=0.5140, second=0.5344)
# Sampled exploitability: avg=0.5194, chi2 p-value=0.3355
#
# 251
# Predicted exploitability: avg=0.5241 (first=0.5139, second=0.5343)
# Sampled exploitability: avg=0.5223, chi2 p-value=0.7164
#
# 252
# Predicted exploitability: avg=0.5240 (first=0.5138, second=0.5343)
# Sampled exploitability: avg=0.5275, chi2 p-value=0.4858
#
# 253
# Predicted exploitability: avg=0.5239 (first=0.5136, second=0.5342)
# Sampled exploitability: avg=0.5258, chi2 p-value=0.7072
#
# 254
# Predicted exploitability: avg=0.5238 (first=0.5135, second=0.5341)
# Sampled exploitability: avg=0.5288, chi2 p-value=0.3197
#
# 255
# Predicted exploitability: avg=0.5237 (first=0.5134, second=0.5341)
# Sampled exploitability: avg=0.5232, chi2 p-value=0.9143
#
# 256
# Predicted exploitability: avg=0.5236 (first=0.5133, second=0.5340)
# Sampled exploitability: avg=0.5270, chi2 p-value=0.5017
#
# 257
# Predicted exploitability: avg=0.5236 (first=0.5132, second=0.5339)
# Sampled exploitability: avg=0.5221, chi2 p-value=0.7711
#
# 258
# Predicted exploitability: avg=0.5235 (first=0.5131, second=0.5339)
# Sampled exploitability: avg=0.5226, chi2 p-value=0.8629
#
# 259
# Predicted exploitability: avg=0.5234 (first=0.5129, second=0.5338)
# Sampled exploitability: avg=0.5179, chi2 p-value=0.2732
#
# 260
# Predicted exploitability: avg=0.5233 (first=0.5128, second=0.5337)
# Sampled exploitability: avg=0.5217, chi2 p-value=0.7514
#
# 261
# Predicted exploitability: avg=0.5232 (first=0.5127, second=0.5337)
# Sampled exploitability: avg=0.5289, chi2 p-value=0.2532
#
# 262
# Predicted exploitability: avg=0.5231 (first=0.5126, second=0.5336)
# Sampled exploitability: avg=0.5110, chi2 p-value=0.01536
#
# 263
# Predicted exploitability: avg=0.5230 (first=0.5125, second=0.5335)
# Sampled exploitability: avg=0.5244, chi2 p-value=0.782
#
# 264
# Predicted exploitability: avg=0.5229 (first=0.5124, second=0.5335)
# Sampled exploitability: avg=0.5236, chi2 p-value=0.8935
#
# 265
# Predicted exploitability: avg=0.5228 (first=0.5123, second=0.5334)
# Sampled exploitability: avg=0.5189, chi2 p-value=0.4296
#
# 266
# Predicted exploitability: avg=0.5228 (first=0.5122, second=0.5333)
# Sampled exploitability: avg=0.5125, chi2 p-value=0.03998
#
# 267
# Predicted exploitability: avg=0.5227 (first=0.5121, second=0.5333)
# Sampled exploitability: avg=0.5303, chi2 p-value=0.1268
#
# 268
# Predicted exploitability: avg=0.5226 (first=0.5120, second=0.5332)
# Sampled exploitability: avg=0.5166, chi2 p-value=0.2304
#
# 269
# Predicted exploitability: avg=0.5225 (first=0.5119, second=0.5332)
# Sampled exploitability: avg=0.5138, chi2 p-value=0.08132
#
# 270
# Predicted exploitability: avg=0.5224 (first=0.5118, second=0.5331)
# Sampled exploitability: avg=0.5184, chi2 p-value=0.4205
#
# 271
# Predicted exploitability: avg=0.5223 (first=0.5116, second=0.5330)
# Sampled exploitability: avg=0.5280, chi2 p-value=0.2572
#
# 272
# Predicted exploitability: avg=0.5223 (first=0.5115, second=0.5330)
# Sampled exploitability: avg=0.5259, chi2 p-value=0.4661
#
# 273
# Predicted exploitability: avg=0.5222 (first=0.5114, second=0.5329)
# Sampled exploitability: avg=0.5279, chi2 p-value=0.252
#
# 274
# Predicted exploitability: avg=0.5221 (first=0.5113, second=0.5329)
# Sampled exploitability: avg=0.5193, chi2 p-value=0.5755
#
# 275
# Predicted exploitability: avg=0.5220 (first=0.5112, second=0.5328)
# Sampled exploitability: avg=0.5179, chi2 p-value=0.4098
#
# 276
# Predicted exploitability: avg=0.5219 (first=0.5111, second=0.5327)
# Sampled exploitability: avg=0.5344, chi2 p-value=0.0126
#
# 277
# Predicted exploitability: avg=0.5219 (first=0.5110, second=0.5327)
# Sampled exploitability: avg=0.5174, chi2 p-value=0.3721
#
# 278
# Predicted exploitability: avg=0.5218 (first=0.5109, second=0.5326)
# Sampled exploitability: avg=0.5247, chi2 p-value=0.5589
#
# 279
# Predicted exploitability: avg=0.5217 (first=0.5108, second=0.5326)
# Sampled exploitability: avg=0.5306, chi2 p-value=0.07489
#
# 280
# Predicted exploitability: avg=0.5216 (first=0.5107, second=0.5325)
# Sampled exploitability: avg=0.5207, chi2 p-value=0.853
#
# 281
# Predicted exploitability: avg=0.5215 (first=0.5107, second=0.5324)
# Sampled exploitability: avg=0.5253, chi2 p-value=0.4527
#
# 282
# Predicted exploitability: avg=0.5215 (first=0.5106, second=0.5324)
# Sampled exploitability: avg=0.5206, chi2 p-value=0.8613
#
# 283
# Predicted exploitability: avg=0.5214 (first=0.5105, second=0.5323)
# Sampled exploitability: avg=0.5160, chi2 p-value=0.28
#
# 284
# Predicted exploitability: avg=0.5213 (first=0.5104, second=0.5323)
# Sampled exploitability: avg=0.5230, chi2 p-value=0.7369
#
# 285
# Predicted exploitability: avg=0.5212 (first=0.5103, second=0.5322)
# Sampled exploitability: avg=0.5169, chi2 p-value=0.3842
#
# 286
# Predicted exploitability: avg=0.5212 (first=0.5102, second=0.5322)
# Sampled exploitability: avg=0.5158, chi2 p-value=0.2821
#
# 287
# Predicted exploitability: avg=0.5211 (first=0.5101, second=0.5321)
# Sampled exploitability: avg=0.5185, chi2 p-value=0.6028
#
# 288
# Predicted exploitability: avg=0.5210 (first=0.5100, second=0.5321)
# Sampled exploitability: avg=0.5209, chi2 p-value=0.9796
#
# 289
# Predicted exploitability: avg=0.5210 (first=0.5099, second=0.5320)
# Sampled exploitability: avg=0.5220, chi2 p-value=0.8343
#
# 290
# Predicted exploitability: avg=0.5209 (first=0.5099, second=0.5319)
# Sampled exploitability: avg=0.5265, chi2 p-value=0.2609
#
# 291
# Predicted exploitability: avg=0.5208 (first=0.5098, second=0.5318)
# Sampled exploitability: avg=0.5330, chi2 p-value=0.0147
#
# 292
# Predicted exploitability: avg=0.5207 (first=0.5098, second=0.5317)
# Sampled exploitability: avg=0.5297, chi2 p-value=0.0729
#
# 293
# Predicted exploitability: avg=0.5207 (first=0.5097, second=0.5316)
# Sampled exploitability: avg=0.5200, chi2 p-value=0.8933
#
# 294
# Predicted exploitability: avg=0.5206 (first=0.5097, second=0.5315)
# Sampled exploitability: avg=0.5214, chi2 p-value=0.8728
#
# 295
# Predicted exploitability: avg=0.5206 (first=0.5096, second=0.5316)
# Sampled exploitability: avg=0.5225, chi2 p-value=0.6987
#
# 296
# Predicted exploitability: avg=0.5205 (first=0.5094, second=0.5316)
# Sampled exploitability: avg=0.5158, chi2 p-value=0.3471
#
# 297
# Predicted exploitability: avg=0.5204 (first=0.5092, second=0.5317)
# Sampled exploitability: avg=0.5187, chi2 p-value=0.7268
#
# 298
# Predicted exploitability: avg=0.5204 (first=0.5091, second=0.5316)
# Sampled exploitability: avg=0.5243, chi2 p-value=0.4323
#
# 299
# Predicted exploitability: avg=0.5203 (first=0.5090, second=0.5316)
# Sampled exploitability: avg=0.5336, chi2 p-value=0.007807
#
# 300
# Predicted exploitability: avg=0.5202 (first=0.5089, second=0.5315)
# Sampled exploitability: avg=0.5197, chi2 p-value=0.9136
#
# 301
# Predicted exploitability: avg=0.5202 (first=0.5089, second=0.5315)
# Sampled exploitability: avg=0.5242, chi2 p-value=0.4204
#
# 302
# Predicted exploitability: avg=0.5201 (first=0.5088, second=0.5314)
# Sampled exploitability: avg=0.5256, chi2 p-value=0.2717
#
# 303
# Predicted exploitability: avg=0.5200 (first=0.5087, second=0.5314)
# Sampled exploitability: avg=0.5181, chi2 p-value=0.6975
#
# 304
# Predicted exploitability: avg=0.5200 (first=0.5086, second=0.5313)
# Sampled exploitability: avg=0.5137, chi2 p-value=0.209
#
# 305
# Predicted exploitability: avg=0.5199 (first=0.5085, second=0.5313)
# Sampled exploitability: avg=0.5233, chi2 p-value=0.4976
#
# 306
# Predicted exploitability: avg=0.5198 (first=0.5084, second=0.5313)
# Sampled exploitability: avg=0.5223, chi2 p-value=0.6233
#
# 307
# Predicted exploitability: avg=0.5198 (first=0.5084, second=0.5312)
# Sampled exploitability: avg=0.5173, chi2 p-value=0.6194
#
# 308
# Predicted exploitability: avg=0.5197 (first=0.5083, second=0.5312)
# Sampled exploitability: avg=0.5225, chi2 p-value=0.5776
#
# 309
# Predicted exploitability: avg=0.5197 (first=0.5082, second=0.5311)
# Sampled exploitability: avg=0.5244, chi2 p-value=0.3422
#
# 310
# Predicted exploitability: avg=0.5196 (first=0.5081, second=0.5311)
# Sampled exploitability: avg=0.5165, chi2 p-value=0.5361
#
# 311
# Predicted exploitability: avg=0.5195 (first=0.5080, second=0.5310)
# Sampled exploitability: avg=0.5227, chi2 p-value=0.5255
#
# 312
# Predicted exploitability: avg=0.5195 (first=0.5080, second=0.5310)
# Sampled exploitability: avg=0.5234, chi2 p-value=0.431
#
# 313
# Predicted exploitability: avg=0.5194 (first=0.5079, second=0.5309)
# Sampled exploitability: avg=0.5255, chi2 p-value=0.2224
#
# 314
# Predicted exploitability: avg=0.5193 (first=0.5078, second=0.5309)
# Sampled exploitability: avg=0.5212, chi2 p-value=0.71
#
# 315
# Predicted exploitability: avg=0.5193 (first=0.5077, second=0.5308)
# Sampled exploitability: avg=0.5220, chi2 p-value=0.5863
#
# 316
# Predicted exploitability: avg=0.5192 (first=0.5077, second=0.5308)
# Sampled exploitability: avg=0.5281, chi2 p-value=0.07552
#
# 317
# Predicted exploitability: avg=0.5192 (first=0.5076, second=0.5307)
# Sampled exploitability: avg=0.5140, chi2 p-value=0.3017
#
# 318
# Predicted exploitability: avg=0.5191 (first=0.5075, second=0.5307)
# Sampled exploitability: avg=0.5202, chi2 p-value=0.8257
#
# 319
# Predicted exploitability: avg=0.5190 (first=0.5074, second=0.5307)
# Sampled exploitability: avg=0.5145, chi2 p-value=0.3635
#
# 320
# Predicted exploitability: avg=0.5190 (first=0.5074, second=0.5306)
# Sampled exploitability: avg=0.5251, chi2 p-value=0.2207
#
# 321
# Predicted exploitability: avg=0.5189 (first=0.5073, second=0.5306)
# Sampled exploitability: avg=0.5147, chi2 p-value=0.3981
#
# 322
# Predicted exploitability: avg=0.5189 (first=0.5072, second=0.5305)
# Sampled exploitability: avg=0.5238, chi2 p-value=0.3231
#
# 323
# Predicted exploitability: avg=0.5188 (first=0.5071, second=0.5305)
# Sampled exploitability: avg=0.5215, chi2 p-value=0.5896
#
# 324
# Predicted exploitability: avg=0.5187 (first=0.5071, second=0.5304)
# Sampled exploitability: avg=0.5206, chi2 p-value=0.7108
#
# 325
# Predicted exploitability: avg=0.5187 (first=0.5070, second=0.5304)
# Sampled exploitability: avg=0.5158, chi2 p-value=0.563
#
# 326
# Predicted exploitability: avg=0.5186 (first=0.5069, second=0.5303)
# Sampled exploitability: avg=0.5214, chi2 p-value=0.5796
#
# 327
# Predicted exploitability: avg=0.5186 (first=0.5068, second=0.5303)
# Sampled exploitability: avg=0.5176, chi2 p-value=0.8452
#
# 328
# Predicted exploitability: avg=0.5185 (first=0.5068, second=0.5303)
# Sampled exploitability: avg=0.5164, chi2 p-value=0.6715
#
# 329
# Predicted exploitability: avg=0.5185 (first=0.5067, second=0.5302)
# Sampled exploitability: avg=0.5194, chi2 p-value=0.8513
#
# 330
# Predicted exploitability: avg=0.5184 (first=0.5066, second=0.5302)
# Sampled exploitability: avg=0.5233, chi2 p-value=0.3275
#
# 331
# Predicted exploitability: avg=0.5184 (first=0.5066, second=0.5301)
# Sampled exploitability: avg=0.5155, chi2 p-value=0.5682
#
# 332
# Predicted exploitability: avg=0.5183 (first=0.5065, second=0.5301)
# Sampled exploitability: avg=0.5193, chi2 p-value=0.8409
#
# 333
# Predicted exploitability: avg=0.5182 (first=0.5064, second=0.5301)
# Sampled exploitability: avg=0.5146, chi2 p-value=0.4661
#
# 334
# Predicted exploitability: avg=0.5182 (first=0.5064, second=0.5300)
# Sampled exploitability: avg=0.5157, chi2 p-value=0.6186
#
# 335
# Predicted exploitability: avg=0.5181 (first=0.5063, second=0.5300)
# Sampled exploitability: avg=0.5226, chi2 p-value=0.3714
#
# 336
# Predicted exploitability: avg=0.5181 (first=0.5062, second=0.5299)
# Sampled exploitability: avg=0.5211, chi2 p-value=0.5455
#
# 337
# Predicted exploitability: avg=0.5180 (first=0.5062, second=0.5299)
# Sampled exploitability: avg=0.5160, chi2 p-value=0.6851
#
# 338
# Predicted exploitability: avg=0.5180 (first=0.5061, second=0.5299)
# Sampled exploitability: avg=0.5227, chi2 p-value=0.3441
#
# 339
# Predicted exploitability: avg=0.5179 (first=0.5060, second=0.5298)
# Sampled exploitability: avg=0.5204, chi2 p-value=0.6197
#
# 340
# Predicted exploitability: avg=0.5179 (first=0.5060, second=0.5298)
# Sampled exploitability: avg=0.5156, chi2 p-value=0.65
#
# 341
# Predicted exploitability: avg=0.5178 (first=0.5059, second=0.5297)
# Sampled exploitability: avg=0.5106, chi2 p-value=0.1488
#
# 342
# Predicted exploitability: avg=0.5178 (first=0.5058, second=0.5297)
# Sampled exploitability: avg=0.5257, chi2 p-value=0.1122
#
# 343
# Predicted exploitability: avg=0.5177 (first=0.5058, second=0.5297)
# Sampled exploitability: avg=0.5169, chi2 p-value=0.871
#
# 344
# Predicted exploitability: avg=0.5177 (first=0.5057, second=0.5296)
# Sampled exploitability: avg=0.5188, chi2 p-value=0.8196
#
# 345
# Predicted exploitability: avg=0.5176 (first=0.5056, second=0.5296)
# Sampled exploitability: avg=0.5314, chi2 p-value=0.005783
#
# 346
# Predicted exploitability: avg=0.5176 (first=0.5056, second=0.5295)
# Sampled exploitability: avg=0.5197, chi2 p-value=0.6682
#
# 347
# Predicted exploitability: avg=0.5175 (first=0.5055, second=0.5295)
# Sampled exploitability: avg=0.5190, chi2 p-value=0.7653
#
# 348
# Predicted exploitability: avg=0.5175 (first=0.5054, second=0.5295)
# Sampled exploitability: avg=0.5215, chi2 p-value=0.4186
#
# 349
# Predicted exploitability: avg=0.5174 (first=0.5054, second=0.5294)
# Sampled exploitability: avg=0.5103, chi2 p-value=0.1549
#
# 350
# Predicted exploitability: avg=0.5174 (first=0.5053, second=0.5294)
# Sampled exploitability: avg=0.5219, chi2 p-value=0.3634
#
# 351
# Predicted exploitability: avg=0.5173 (first=0.5053, second=0.5294)
# Sampled exploitability: avg=0.5127, chi2 p-value=0.3563
#
# 352
# Predicted exploitability: avg=0.5173 (first=0.5052, second=0.5293)
# Sampled exploitability: avg=0.5136, chi2 p-value=0.4639
#
# 353
# Predicted exploitability: avg=0.5172 (first=0.5051, second=0.5293)
# Sampled exploitability: avg=0.5211, chi2 p-value=0.4365
#
# 354
# Predicted exploitability: avg=0.5172 (first=0.5051, second=0.5293)
# Sampled exploitability: avg=0.5233, chi2 p-value=0.2194
#
# 355
# Predicted exploitability: avg=0.5171 (first=0.5050, second=0.5292)
# Sampled exploitability: avg=0.5228, chi2 p-value=0.2552
#
# 356
# Predicted exploitability: avg=0.5171 (first=0.5049, second=0.5292)
# Sampled exploitability: avg=0.5154, chi2 p-value=0.7387
#
# 357
# Predicted exploitability: avg=0.5170 (first=0.5049, second=0.5291)
# Sampled exploitability: avg=0.5135, chi2 p-value=0.4813
#
# 358
# Predicted exploitability: avg=0.5170 (first=0.5048, second=0.5291)
# Sampled exploitability: avg=0.5106, chi2 p-value=0.2023
#
# 359
# Predicted exploitability: avg=0.5169 (first=0.5048, second=0.5291)
# Sampled exploitability: avg=0.5190, chi2 p-value=0.6779
#
# 360
# Predicted exploitability: avg=0.5169 (first=0.5047, second=0.5290)
# Sampled exploitability: avg=0.5117, chi2 p-value=0.3002
#
# 361
# Predicted exploitability: avg=0.5168 (first=0.5047, second=0.5290)
# Sampled exploitability: avg=0.5133, chi2 p-value=0.4798
#
# 362
# Predicted exploitability: avg=0.5168 (first=0.5046, second=0.5290)
# Sampled exploitability: avg=0.5181, chi2 p-value=0.7924
#
# 363
# Predicted exploitability: avg=0.5167 (first=0.5045, second=0.5289)
# Sampled exploitability: avg=0.5190, chi2 p-value=0.6509
#
# 364
# Predicted exploitability: avg=0.5167 (first=0.5045, second=0.5289)
# Sampled exploitability: avg=0.5126, chi2 p-value=0.4128
#
# 365
# Predicted exploitability: avg=0.5166 (first=0.5044, second=0.5289)
# Sampled exploitability: avg=0.5139, chi2 p-value=0.5825
#
# 366
# Predicted exploitability: avg=0.5166 (first=0.5044, second=0.5288)
# Sampled exploitability: avg=0.5153, chi2 p-value=0.7945
#
# 367
# Predicted exploitability: avg=0.5166 (first=0.5043, second=0.5288)
# Sampled exploitability: avg=0.5257, chi2 p-value=0.0673
#
# 368
# Predicted exploitability: avg=0.5165 (first=0.5043, second=0.5288)
# Sampled exploitability: avg=0.5162, chi2 p-value=0.9503
#
# 369
# Predicted exploitability: avg=0.5165 (first=0.5042, second=0.5287)
# Sampled exploitability: avg=0.5220, chi2 p-value=0.2682
#
# 370
# Predicted exploitability: avg=0.5164 (first=0.5041, second=0.5287)
# Sampled exploitability: avg=0.5209, chi2 p-value=0.3703
#
# 371
# Predicted exploitability: avg=0.5164 (first=0.5041, second=0.5287)
# Sampled exploitability: avg=0.5137, chi2 p-value=0.592
#
# 372
# Predicted exploitability: avg=0.5163 (first=0.5040, second=0.5286)
# Sampled exploitability: avg=0.5229, chi2 p-value=0.1889
#
# 373
# Predicted exploitability: avg=0.5163 (first=0.5040, second=0.5286)
# Sampled exploitability: avg=0.5131, chi2 p-value=0.5231
#
# 374
# Predicted exploitability: avg=0.5162 (first=0.5039, second=0.5286)
# Sampled exploitability: avg=0.5200, chi2 p-value=0.4527
#
# 375
# Predicted exploitability: avg=0.5162 (first=0.5039, second=0.5285)
# Sampled exploitability: avg=0.5053, chi2 p-value=0.02911
#
# 376
# Predicted exploitability: avg=0.5162 (first=0.5038, second=0.5285)
# Sampled exploitability: avg=0.5211, chi2 p-value=0.323
#
# 377
# Predicted exploitability: avg=0.5161 (first=0.5038, second=0.5285)
# Sampled exploitability: avg=0.5150, chi2 p-value=0.8229
#
# 378
# Predicted exploitability: avg=0.5161 (first=0.5037, second=0.5284)
# Sampled exploitability: avg=0.5223, chi2 p-value=0.213
#
# 379
# Predicted exploitability: avg=0.5160 (first=0.5037, second=0.5284)
# Sampled exploitability: avg=0.5111, chi2 p-value=0.3235
#
# 380
# Predicted exploitability: avg=0.5160 (first=0.5036, second=0.5284)
# Sampled exploitability: avg=0.5082, chi2 p-value=0.119
#
# 381
# Predicted exploitability: avg=0.5159 (first=0.5035, second=0.5284)
# Sampled exploitability: avg=0.5192, chi2 p-value=0.5154
#
# 382
# Predicted exploitability: avg=0.5159 (first=0.5035, second=0.5283)
# Sampled exploitability: avg=0.5174, chi2 p-value=0.7653
#
# 383
# Predicted exploitability: avg=0.5159 (first=0.5034, second=0.5283)
# Sampled exploitability: avg=0.5120, chi2 p-value=0.4391
#
# 384
# Predicted exploitability: avg=0.5158 (first=0.5034, second=0.5283)
# Sampled exploitability: avg=0.5098, chi2 p-value=0.2279
#
# 385
# Predicted exploitability: avg=0.5158 (first=0.5033, second=0.5282)
# Sampled exploitability: avg=0.5194, chi2 p-value=0.4694
#
# 386
# Predicted exploitability: avg=0.5157 (first=0.5033, second=0.5282)
# Sampled exploitability: avg=0.5153, chi2 p-value=0.9293
#
# 387
# Predicted exploitability: avg=0.5157 (first=0.5032, second=0.5282)
# Sampled exploitability: avg=0.5098, chi2 p-value=0.2375
#
# 388
# Predicted exploitability: avg=0.5157 (first=0.5032, second=0.5281)
# Sampled exploitability: avg=0.5152, chi2 p-value=0.9262
#
# 389
# Predicted exploitability: avg=0.5156 (first=0.5031, second=0.5281)
# Sampled exploitability: avg=0.5087, chi2 p-value=0.166
#
# 390
# Predicted exploitability: avg=0.5156 (first=0.5031, second=0.5281)
# Sampled exploitability: avg=0.5119, chi2 p-value=0.4612
#
# 391
# Predicted exploitability: avg=0.5155 (first=0.5030, second=0.5280)
# Sampled exploitability: avg=0.5152, chi2 p-value=0.9453
#
# 392
# Predicted exploitability: avg=0.5155 (first=0.5030, second=0.5280)
# Sampled exploitability: avg=0.5073, chi2 p-value=0.1007
#
# 393
# Predicted exploitability: avg=0.5155 (first=0.5029, second=0.5280)
# Sampled exploitability: avg=0.5162, chi2 p-value=0.8829
#
# 394
# Predicted exploitability: avg=0.5154 (first=0.5029, second=0.5280)
# Sampled exploitability: avg=0.5234, chi2 p-value=0.1105
#
# 395
# Predicted exploitability: avg=0.5154 (first=0.5028, second=0.5279)
# Sampled exploitability: avg=0.5150, chi2 p-value=0.9385
#
# 396
# Predicted exploitability: avg=0.5153 (first=0.5028, second=0.5279)
# Sampled exploitability: avg=0.5194, chi2 p-value=0.4174
#
# 397
# Predicted exploitability: avg=0.5153 (first=0.5027, second=0.5279)
# Sampled exploitability: avg=0.5070, chi2 p-value=0.09641
#
# 398
# Predicted exploitability: avg=0.5153 (first=0.5027, second=0.5278)
# Sampled exploitability: avg=0.5119, chi2 p-value=0.5001
#
# 399
# Predicted exploitability: avg=0.5152 (first=0.5026, second=0.5278)
# Sampled exploitability: avg=0.5241, chi2 p-value=0.07599
#
# 400
# Predicted exploitability: avg=0.5152 (first=0.5026, second=0.5278)
# Sampled exploitability: avg=0.5181, chi2 p-value=0.5609
#
# 401
# Predicted exploitability: avg=0.5152 (first=0.5026, second=0.5278)
# Sampled exploitability: avg=0.5140, chi2 p-value=0.817
#
# 402
# Predicted exploitability: avg=0.5151 (first=0.5025, second=0.5277)
# Sampled exploitability: avg=0.5178, chi2 p-value=0.5916
#
# 403
# Predicted exploitability: avg=0.5151 (first=0.5025, second=0.5277)
# Sampled exploitability: avg=0.5137, chi2 p-value=0.7823
#
# 404
# Predicted exploitability: avg=0.5150 (first=0.5024, second=0.5277)
# Sampled exploitability: avg=0.5201, chi2 p-value=0.3117
#
# 405
# Predicted exploitability: avg=0.5150 (first=0.5024, second=0.5277)
# Sampled exploitability: avg=0.5156, chi2 p-value=0.9055
#
# 406
# Predicted exploitability: avg=0.5150 (first=0.5023, second=0.5276)
# Sampled exploitability: avg=0.5198, chi2 p-value=0.3338
#
# 407
# Predicted exploitability: avg=0.5149 (first=0.5023, second=0.5276)
# Sampled exploitability: avg=0.5157, chi2 p-value=0.8781
#
# 408
# Predicted exploitability: avg=0.5149 (first=0.5022, second=0.5276)
# Sampled exploitability: avg=0.5202, chi2 p-value=0.2886
#
# 409
# Predicted exploitability: avg=0.5149 (first=0.5022, second=0.5275)
# Sampled exploitability: avg=0.5154, chi2 p-value=0.914
#
# 410
# Predicted exploitability: avg=0.5148 (first=0.5021, second=0.5275)
# Sampled exploitability: avg=0.5090, chi2 p-value=0.2439
#
# 411
# Predicted exploitability: avg=0.5148 (first=0.5021, second=0.5275)
# Sampled exploitability: avg=0.5215, chi2 p-value=0.1793
#
# 412
# Predicted exploitability: avg=0.5148 (first=0.5020, second=0.5275)
# Sampled exploitability: avg=0.5194, chi2 p-value=0.3524
#
# 413
# Predicted exploitability: avg=0.5147 (first=0.5020, second=0.5274)
# Sampled exploitability: avg=0.5160, chi2 p-value=0.7974
#
# 414
# Predicted exploitability: avg=0.5147 (first=0.5020, second=0.5274)
# Sampled exploitability: avg=0.5091, chi2 p-value=0.2641
#
# 415
# Predicted exploitability: avg=0.5146 (first=0.5019, second=0.5274)
# Sampled exploitability: avg=0.5165, chi2 p-value=0.7107
#
# 416
# Predicted exploitability: avg=0.5146 (first=0.5019, second=0.5274)
# Sampled exploitability: avg=0.5204, chi2 p-value=0.2467
#
# 417
# Predicted exploitability: avg=0.5146 (first=0.5018, second=0.5273)
# Sampled exploitability: avg=0.5139, chi2 p-value=0.8924
#
# 418
# Predicted exploitability: avg=0.5145 (first=0.5018, second=0.5273)
# Sampled exploitability: avg=0.5136, chi2 p-value=0.8506
#
# 419
# Predicted exploitability: avg=0.5145 (first=0.5017, second=0.5273)
# Sampled exploitability: avg=0.5186, chi2 p-value=0.4128
#
# 420

# %%
curr_av.store_efficiently('/root/liars_poker/artifacts/runs/run_temp_105')
