# %% [markdown]
# # Dense CFR Sanity Checks
#
# Quick correctness and blocker-aware checks for the dense CFR implementation.

# %%
import os, sys
from pathlib import Path

# Add repo root to sys.path

def find_repo_root(start_dir: str) -> str:
    cur = Path(start_dir).resolve()
    for _ in range(6):
        if (cur / "liars_poker").is_dir() or (cur / "pyproject.toml").exists():
            return str(cur)
        if cur.parent == cur:
            break
        cur = cur.parent
    return str(Path(start_dir).resolve())

NB_DIR = Path.cwd()
REPO_ROOT = Path(find_repo_root(NB_DIR))
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from liars_poker.core import GameSpec
from liars_poker.infoset import CALL
from liars_poker.policies.tabular_dense import DenseTabularPolicy
from liars_poker.algo.cfr_exact_dense import CFRExactDense
from liars_poker.algo.br_exact_dense_to_dense import best_response_dense

# %% [markdown]
# ## Test 1: Strategy validity (legal actions only, rows sum to 1)

# %%
spec = GameSpec(ranks=3, suits=2, hand_size=1, claim_kinds=("RankHigh", "Pair"))

cfr = CFRExactDense(spec)
for _ in range(5):
    cfr.iterate()

avg_policy = cfr.average_policy()

# Check a few random hids and hands for correct normalization over legal actions
H, N, A = avg_policy.S.shape
for hid in [0, 1, 2, 3, 4, 5]:
    legal = avg_policy.legal_actions[hid]
    if not legal:
        continue
    cols = [0 if a == CALL else a + 1 for a in legal]
    row = avg_policy.S[hid, 0, cols]
    assert abs(float(row.sum()) - 1.0) < 1e-6, (hid, row.sum())

# CALL should be illegal at root (hid=0), so column 0 should be zero there
assert float(avg_policy.S[0, 0, 0]) == 0.0
print('Test 1 passed')
# Out:
# Test 1 passed

# %% [markdown]
# ## Test 2: Exploitability trend (small spec, few iterations)

# %%
spec = GameSpec(ranks=2, suits=4, hand_size=2, claim_kinds=("RankHigh", "Pair"))

cfr = CFRExactDense(spec)

episodes = 100
results = {}
for t in range(episodes + 1):

    cfr.iterate()

    avg_policy = cfr.average_policy()
    br_pol, meta = best_response_dense(spec, avg_policy, debug=False)
    p1, p2 = meta["computer"].exploitability()
    results[t] = (p1, p2, 0.5 * (p1 + p2))


    print(f"iter={t}: p_first={p1:.6f}, p_second={p2:.6f}, avg={0.5 * (p1 + p2):.6f}")

# Qualitative check: later iterations should not be worse in this tiny game
assert results[episodes][2] <= results[0][2] + 1e-6
print('Test 2 completed')
# Out:
# iter=0: p_first=0.842857, p_second=0.671429, avg=0.757143
# iter=1: p_first=0.821429, p_second=0.438187, avg=0.629808
# iter=2: p_first=0.814286, p_second=0.358791, avg=0.586538
# iter=3: p_first=0.810714, p_second=0.319093, avg=0.564904
# iter=4: p_first=0.808571, p_second=0.295275, avg=0.551923
# iter=5: p_first=0.807143, p_second=0.279396, avg=0.543269
# iter=6: p_first=0.806122, p_second=0.268053, avg=0.537088
# iter=7: p_first=0.805357, p_second=0.259547, avg=0.532452
# iter=8: p_first=0.804762, p_second=0.252930, avg=0.528846
# iter=9: p_first=0.804286, p_second=0.247637, avg=0.525962
# iter=10: p_first=0.803896, p_second=0.243307, avg=0.523601
# iter=11: p_first=0.803571, p_second=0.239698, avg=0.521635
# iter=12: p_first=0.803297, p_second=0.236644, avg=0.519970
# iter=13: p_first=0.803061, p_second=0.234027, avg=0.518544
# iter=14: p_first=0.802857, p_second=0.231758, avg=0.517308
# iter=15: p_first=0.802679, p_second=0.229773, avg=0.516226
# iter=16: p_first=0.802521, p_second=0.228022, avg=0.515271
# iter=17: p_first=0.802381, p_second=0.226465, avg=0.514423
# iter=18: p_first=0.802256, p_second=0.225072, avg=0.513664
# iter=19: p_first=0.802143, p_second=0.223819, avg=0.512981
# iter=20: p_first=0.802041, p_second=0.222684, avg=0.512363
# iter=21: p_first=0.801948, p_second=0.221653, avg=0.511801
# iter=22: p_first=0.801863, p_second=0.220712, avg=0.511288
# iter=23: p_first=0.801786, p_second=0.219849, avg=0.510817
# iter=24: p_first=0.801714, p_second=0.219055, avg=0.510385
# iter=25: p_first=0.801648, p_second=0.218322, avg=0.509985
# iter=26: p_first=0.801587, p_second=0.217643, avg=0.509615
# iter=27: p_first=0.801531, p_second=0.217013, avg=0.509272
# iter=28: p_first=0.801478, p_second=0.216427, avg=0.508952
# iter=29: p_first=0.801429, p_second=0.215879, avg=0.508654
# iter=30: p_first=0.801382, p_second=0.215367, avg=0.508375
# iter=31: p_first=0.801339, p_second=0.214887, avg=0.508113
# iter=32: p_first=0.801299, p_second=0.214436, avg=0.507867
# iter=33: p_first=0.801261, p_second=0.214011, avg=0.507636
# iter=34: p_first=0.801224, p_second=0.213611, avg=0.507418
# iter=35: p_first=0.801190, p_second=0.213233, avg=0.507212
# iter=36: p_first=0.801158, p_second=0.212875, avg=0.507017
# iter=37: p_first=0.801128, p_second=0.212536, avg=0.506832
# iter=38: p_first=0.801099, p_second=0.212215, avg=0.506657
# iter=39: p_first=0.801071, p_second=0.211909, avg=0.506490
# iter=40: p_first=0.801045, p_second=0.211619, avg=0.506332
# iter=41: p_first=0.801020, p_second=0.211342, avg=0.506181
# iter=42: p_first=0.800997, p_second=0.211078, avg=0.506038
# iter=43: p_first=0.800974, p_second=0.210827, avg=0.505900
# iter=44: p_first=0.800952, p_second=0.210586, avg=0.505769
# iter=45: p_first=0.800932, p_second=0.210356, avg=0.505644
# iter=46: p_first=0.800912, p_second=0.210136, avg=0.505524
# iter=47: p_first=0.800893, p_second=0.209924, avg=0.505409
# iter=48: p_first=0.800875, p_second=0.209722, avg=0.505298
# iter=49: p_first=0.800857, p_second=0.209527, avg=0.505192
# iter=50: p_first=0.800840, p_second=0.209341, avg=0.505090
# iter=51: p_first=0.800824, p_second=0.209161, avg=0.504993
# iter=52: p_first=0.800809, p_second=0.208988, avg=0.504898
# iter=53: p_first=0.800794, p_second=0.208822, avg=0.504808
# iter=54: p_first=0.800779, p_second=0.208661, avg=0.504720
# iter=55: p_first=0.800765, p_second=0.208507, avg=0.504636
# iter=56: p_first=0.800752, p_second=0.208357, avg=0.504555
# iter=57: p_first=0.800739, p_second=0.208213, avg=0.504476
# iter=58: p_first=0.800726, p_second=0.208074, avg=0.504400
# iter=59: p_first=0.800714, p_second=0.207940, avg=0.504327
# iter=60: p_first=0.800703, p_second=0.207809, avg=0.504256
# iter=61: p_first=0.800691, p_second=0.207683, avg=0.504187
# iter=62: p_first=0.800680, p_second=0.207561, avg=0.504121
# iter=63: p_first=0.800670, p_second=0.207443, avg=0.504056
# iter=64: p_first=0.800659, p_second=0.207329, avg=0.503994
# iter=65: p_first=0.800649, p_second=0.207218, avg=0.503934
# iter=66: p_first=0.800640, p_second=0.207110, avg=0.503875
# iter=67: p_first=0.800630, p_second=0.207005, avg=0.503818
# iter=68: p_first=0.800621, p_second=0.206904, avg=0.503763
# iter=69: p_first=0.800612, p_second=0.206805, avg=0.503709
# iter=70: p_first=0.800604, p_second=0.206709, avg=0.503657
# iter=71: p_first=0.800595, p_second=0.206616, avg=0.503606
# iter=72: p_first=0.800587, p_second=0.206526, avg=0.503556
# iter=73: p_first=0.800579, p_second=0.206437, avg=0.503508
# iter=74: p_first=0.800571, p_second=0.206352, avg=0.503462
# iter=75: p_first=0.800564, p_second=0.206268, avg=0.503416
# iter=76: p_first=0.800557, p_second=0.206187, avg=0.503372
# iter=77: p_first=0.800549, p_second=0.206107, avg=0.503328
# iter=78: p_first=0.800542, p_second=0.206030, avg=0.503286
# iter=79: p_first=0.800536, p_second=0.205955, avg=0.503245
# iter=80: p_first=0.800529, p_second=0.205881, avg=0.503205
# iter=81: p_first=0.800523, p_second=0.205809, avg=0.503166
# iter=82: p_first=0.800516, p_second=0.205739, avg=0.503128
# iter=83: p_first=0.800510, p_second=0.205671, avg=0.503091
# iter=84: p_first=0.800504, p_second=0.205604, avg=0.503054
# iter=85: p_first=0.800498, p_second=0.205539, avg=0.503019
# iter=86: p_first=0.800493, p_second=0.205476, avg=0.502984
# iter=87: p_first=0.800487, p_second=0.205413, avg=0.502950
# iter=88: p_first=0.800482, p_second=0.205353, avg=0.502917
# iter=89: p_first=0.800476, p_second=0.205293, avg=0.502885
# iter=90: p_first=0.800471, p_second=0.205235, avg=0.502853
# iter=91: p_first=0.800466, p_second=0.205178, avg=0.502822
# iter=92: p_first=0.800461, p_second=0.205122, avg=0.502792
# iter=93: p_first=0.800456, p_second=0.205068, avg=0.502762
# iter=94: p_first=0.800451, p_second=0.205014, avg=0.502733
# iter=95: p_first=0.800446, p_second=0.204962, avg=0.502704
# iter=96: p_first=0.800442, p_second=0.204911, avg=0.502676
# iter=97: p_first=0.800437, p_second=0.204861, avg=0.502649
# iter=98: p_first=0.800433, p_second=0.204812, avg=0.502622
# iter=99: p_first=0.800429, p_second=0.204764, avg=0.502596
# iter=100: p_first=0.800424, p_second=0.204717, avg=0.502570
# Test 2 completed

# %%
from liars_poker.training.dense_fsp import dense_fsp_loop
pol1, info1 = dense_fsp_loop(spec=spec, episodes=episodes, episodes_test=0, efficient=True)
# Out:
# Predicted exploitability: avg=0.757142857 (first=0.8429, second=0.6714)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.628571429 (first=0.8214, second=0.4357)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.585714287 (first=0.8143, second=0.3571)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.564285714 (first=0.8107, second=0.3179)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.551428571 (first=0.8086, second=0.2943)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.542857143 (first=0.8071, second=0.2786)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.536734696 (first=0.8061, second=0.2673)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.532142857 (first=0.8054, second=0.2589)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.528571428 (first=0.8048, second=0.2524)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.525714286 (first=0.8043, second=0.2471)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.523376623 (first=0.8039, second=0.2429)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.521428571 (first=0.8036, second=0.2393)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.519780219 (first=0.8033, second=0.2363)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.518367346 (first=0.8031, second=0.2337)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.517142856 (first=0.8029, second=0.2314)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.516071427 (first=0.8027, second=0.2295)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.515126049 (first=0.8025, second=0.2277)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.514285711 (first=0.8024, second=0.2262)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.513533832 (first=0.8023, second=0.2248)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.512857140 (first=0.8021, second=0.2236)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.512244896 (first=0.8020, second=0.2224)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.511688309 (first=0.8019, second=0.2214)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.511180122 (first=0.8019, second=0.2205)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.510714284 (first=0.8018, second=0.2196)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.510285712 (first=0.8017, second=0.2189)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.509890106 (first=0.8016, second=0.2181)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.509523807 (first=0.8016, second=0.2175)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.509183672 (first=0.8015, second=0.2168)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.508866994 (first=0.8015, second=0.2163)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.508571427 (first=0.8014, second=0.2157)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.508294928 (first=0.8014, second=0.2152)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.508035712 (first=0.8013, second=0.2147)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.507792207 (first=0.8013, second=0.2143)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.507563024 (first=0.8013, second=0.2139)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.507346938 (first=0.8012, second=0.2135)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.507142855 (first=0.8012, second=0.2131)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.506949806 (first=0.8012, second=0.2127)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.506766916 (first=0.8011, second=0.2124)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.506593406 (first=0.8011, second=0.2121)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.506428571 (first=0.8011, second=0.2118)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.506271776 (first=0.8010, second=0.2115)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.506122447 (first=0.8010, second=0.2112)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505980064 (first=0.8010, second=0.2110)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505844155 (first=0.8010, second=0.2107)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505714285 (first=0.8010, second=0.2105)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505590061 (first=0.8009, second=0.2102)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505471124 (first=0.8009, second=0.2100)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505357142 (first=0.8009, second=0.2098)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505247813 (first=0.8009, second=0.2096)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505142857 (first=0.8009, second=0.2094)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.505042016 (first=0.8008, second=0.2092)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504945053 (first=0.8008, second=0.2091)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504851750 (first=0.8008, second=0.2089)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504761903 (first=0.8008, second=0.2087)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504675323 (first=0.8008, second=0.2086)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504591835 (first=0.8008, second=0.2084)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504511277 (first=0.8008, second=0.2083)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504433497 (first=0.8007, second=0.2081)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504358353 (first=0.8007, second=0.2080)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504285714 (first=0.8007, second=0.2079)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504215456 (first=0.8007, second=0.2077)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504147465 (first=0.8007, second=0.2076)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504081632 (first=0.8007, second=0.2075)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.504017857 (first=0.8007, second=0.2074)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503956043 (first=0.8007, second=0.2073)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503896104 (first=0.8006, second=0.2071)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503837953 (first=0.8006, second=0.2070)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503781511 (first=0.8006, second=0.2069)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503726706 (first=0.8006, second=0.2068)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503673466 (first=0.8006, second=0.2067)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503621727 (first=0.8006, second=0.2066)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503571426 (first=0.8006, second=0.2065)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503522502 (first=0.8006, second=0.2065)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503474901 (first=0.8006, second=0.2064)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503428569 (first=0.8006, second=0.2063)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503383456 (first=0.8006, second=0.2062)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503339515 (first=0.8006, second=0.2061)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503296700 (first=0.8005, second=0.2060)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503254970 (first=0.8005, second=0.2060)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503214283 (first=0.8005, second=0.2059)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503174600 (first=0.8005, second=0.2058)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503135885 (first=0.8005, second=0.2057)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503098104 (first=0.8005, second=0.2057)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503061221 (first=0.8005, second=0.2056)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.503025207 (first=0.8005, second=0.2055)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502990030 (first=0.8005, second=0.2055)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502955661 (first=0.8005, second=0.2054)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502922073 (first=0.8005, second=0.2054)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502889241 (first=0.8005, second=0.2053)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502857138 (first=0.8005, second=0.2052)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502825741 (first=0.8005, second=0.2052)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502795027 (first=0.8005, second=0.2051)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502764972 (first=0.8005, second=0.2051)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502735559 (first=0.8005, second=0.2050)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502706765 (first=0.8005, second=0.2050)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502678569 (first=0.8004, second=0.2049)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502650955 (first=0.8004, second=0.2049)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502623905 (first=0.8004, second=0.2048)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502597399 (first=0.8004, second=0.2048)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan
#
# Predicted exploitability: avg=0.502571425 (first=0.8004, second=0.2047)
# Sampled exploitability: avg=0.0000 (BR as P1=0.0000, BR as P2=0.0000), chi2 p-value=nan

# %% [markdown]
# ## Test 3: Blocker asymmetry check (suit-symmetric deck)
#
# Find at least one pair of hands where A0 and A1 differ.

# %%
spec = GameSpec(ranks=3, suits=4, hand_size=2, claim_kinds=("RankHigh",), suit_symmetry=True)

cfr = CFRExactDense(spec)
A0 = cfr.A0
A1 = cfr.A1

found = None
for i in range(cfr.n_hands):
    for j in range(cfr.n_hands):
        if abs(A0[i, j] - A1[j, i]) > 1e-9:
            found = (i, j, A0[i, j], A1[j, i])
            break
    if found:
        break

if found:
    i, j, a0, a1 = found
    print(f"Found asymmetry at hands {i},{j}: A0={a0}, A1^T={a1}")
else:
    print('No asymmetry found in this spec (possible but unlikely); matrices still computed separately.')
# Out:
# Found asymmetry at hands 0,1: A0=8.0, A1^T=3.0

# %%
from datetime import datetime
from pathlib import Path

from liars_poker.core import GameSpec, ARTIFACTS_ROOT
from liars_poker.training.cfr_dense import (
    cfr_dense_loop,
    cfr_dense_resume,
    save_cfr_run,
    load_cfr_state,
)

spec = GameSpec(ranks=2, suits=2, hand_size=1, claim_kinds=("RankHigh",), suit_symmetry=True)
run_id = f"cfr_demo_{datetime.now().strftime('%Y%m%d-%H%M%S')}"

policy, logs, cfr = cfr_dense_loop(spec, iterations=5, eval_every=1)
save_cfr_run(
    run_id=run_id,
    policy=policy,
    cfr=cfr,
    logs=logs,
    spec=spec,
    iterations_done=5,
    eval_every=1,
)

run_dir = Path(ARTIFACTS_ROOT) / 'benchmark_runs' / run_id
cfr_loaded, spec_loaded, metrics, iter_done = load_cfr_state(run_dir)
print('Loaded', spec_loaded, 'iter_done', iter_done)
print('Metrics keys:', list(metrics.keys()))

# Resume for a few more iterations
policy2, logs2, cfr2, spec2, total_iters = cfr_dense_resume(
    run_dir, remaining_iterations=3, eval_every=0
)
print('Resumed to total_iters', total_iters)
# Out:
# [cfr] iter=1 elapsed=0.00s
# [cfr] iter=2 elapsed=0.01s
# [cfr] iter=3 elapsed=0.01s
# [cfr] iter=4 elapsed=0.01s
# [cfr] iter=5 elapsed=0.02s
# Loaded GameSpec(ranks=2, suits=2, hand_size=1, claim_kinds=('RankHigh',), suit_symmetry=True) iter_done 5
# Metrics keys: ['run_type', 'spec', 'iterations', 'eval_every', 'exploitability_series', 'timestamp']
# [cfr] iter=6 elapsed=0.00s
# [cfr] iter=7 elapsed=0.00s
# [cfr] iter=8 elapsed=0.00s
# Resumed to total_iters 8

# %% [markdown]
# ## CFR+ Sanity Check
# Run a tiny CFR+ loop and verify logging + resume paths.

# %%
from datetime import datetime
from pathlib import Path

from liars_poker.core import GameSpec, ARTIFACTS_ROOT
from liars_poker.training.cfr_plus_dense import (
    cfr_plus_loop,
    cfr_plus_resume,
    save_cfr_plus_run,
    load_cfr_plus_state,
)

spec = GameSpec(ranks=4, suits=2, hand_size=2, claim_kinds=("RankHigh", "Pair"), suit_symmetry=True)
run_id = f"cfr_plus_demo_{datetime.now().strftime('%Y%m%d-%H%M%S')}"

policy, logs, cfr = cfr_plus_loop(spec, iterations=100, eval_every=1, debug=True)


# save_cfr_plus_run(
#     run_id=run_id,
#     policy=policy,
#     cfr=cfr,
#     logs=logs,
#     spec=spec,
#     iterations_done=4,
#     eval_every=0,
# )

# run_dir = Path(ARTIFACTS_ROOT) / 'benchmark_runs' / run_id
# cfr_loaded, spec_loaded, metrics, iter_done = load_cfr_plus_state(run_dir)
# print('Loaded CFR+ spec', spec_loaded, 'iter_done', iter_done)

# policy2, logs2, cfr2, spec2, total_iters = cfr_plus_resume(
#     run_dir, remaining_iterations=2, eval_every=0
# )
# print('Resumed CFR+ to total_iters', total_iters)
# Out:
# [cfr+] iter=1 elapsed=0.14s exploitability_avg=0.826565
# [cfr+] iter=1 elapsed=0.14s
# [cfr+] iter=2 elapsed=0.24s exploitability_avg=0.697315
# [cfr+] iter=2 elapsed=0.24s
# [cfr+] iter=3 elapsed=0.34s exploitability_avg=0.657405
# [cfr+] iter=3 elapsed=0.34s
# [cfr+] iter=4 elapsed=0.45s exploitability_avg=0.643433
# [cfr+] iter=4 elapsed=0.45s
# [cfr+] iter=5 elapsed=0.55s exploitability_avg=0.623602
# [cfr+] iter=5 elapsed=0.55s
# [cfr+] iter=6 elapsed=0.65s exploitability_avg=0.597583
# [cfr+] iter=6 elapsed=0.65s
# [cfr+] iter=7 elapsed=0.76s exploitability_avg=0.592425
# [cfr+] iter=7 elapsed=0.76s
# [cfr+] iter=8 elapsed=0.86s exploitability_avg=0.617563
# [cfr+] iter=8 elapsed=0.86s
# [cfr+] iter=9 elapsed=0.96s exploitability_avg=0.622712
# [cfr+] iter=9 elapsed=0.96s
# [cfr+] iter=10 elapsed=1.06s exploitability_avg=0.604178
# [cfr+] iter=10 elapsed=1.06s
# [cfr+] iter=11 elapsed=1.16s exploitability_avg=0.591305
# [cfr+] iter=11 elapsed=1.16s
